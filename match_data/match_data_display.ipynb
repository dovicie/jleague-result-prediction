# %%
import pandas as pd

# %%
df= pd.read_csv("shim_2020.csv")

# %%
df
# Out:
#      節    開催日 Unnamed: 2    相手  スコア Unnamed: 5    会場     観客数        天候  AGI  \
# 0    1   2.23        (日)  FC東京  1-3          H  アイスタ  17,549         晴   61
# 1    2   7.40        (土)   名古屋  1-2          H  アイスタ       0         雨   53
# 2    3   7.80        (水)   Ｃ大阪  0-2          A  ヤンマー       0         曇   41
# 3    4   7.12        (日)   Ｇ大阪  1-2          H  アイスタ   4,131         曇   60
# 4    5   7.18        (土)    神戸  1-3          A  ノエスタ   3,494         晴   50
# 5    6   7.22        (水)    鳥栖  1-1          A   駅スタ   3,117      曇のち雨   50
# 6    7   7.26        (日)    大分  4-2          H  アイスタ   2,697  雨のち雷雨のち雨   56
# 7    8   8.10        (土)    浦和  1-1          A    埼玉   4,237         晴   61
# 8    9   8.80        (土)    札幌  3-1          H  アイスタ   3,981         晴   58
# 9   10   8.15        (土)    仙台  0-0          A  ユアスタ   2,718         晴   54
# 10  11   8.19        (水)  横浜FM  3-4          H  アイスタ   3,279         曇   47
# ...
