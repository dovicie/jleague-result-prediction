# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mglearn
from sklearn import svm
import datetime as dt
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("./match_data_yearly/all_years.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index(df["Date"])

# %%
df
# Out:
#             Year  Sec       Date                  Home                 Away  \
# Date
# 2006-03-04  2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 2006-03-05  2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 2006-03-05  2006    1 2006-03-05              fc-tokyo         oita-trinita
# 2006-03-05  2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 2006-03-05  2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...          ...  ...        ...                   ...                  ...
# 2020-12-19  2020   34 2020-12-19       kashima-antlers         cerezo-osaka
# 2020-12-19  2020   34 2020-12-19  nagoya-grampus-eight  sanfrecce-hiroshima
# 2020-12-19  2020   34 2020-12-19            sagan-tosu         oita-trinita
# 2020-12-19  2020   34 2020-12-19              fc-tokyo          vissel-kobe
# 2020-12-19  2020   34 2020-12-19    urawa-red-diamonds    consadole-sapporo
#
#             HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  Attendances  \
# Date
# 2006-03-04       9       3       1       1    0      万博        20916
# 2006-03-05      28       7       0       2    2      小瀬        14277
# 2006-03-05      22      31       2       0    1     味スタ        22531
# 2006-03-05      13      23       1       1    0      静岡        28564
# 2006-03-05       8      20       3       2    1     瑞穂陸        17199
# ...            ...     ...     ...     ...  ...     ...          ...
# 2020-12-19       1      20       1       1    0     カシマ        11251
# 2020-12-19       8      10       1       0    1     豊田ス        16825
# 2020-12-19      33      31       2       2    0     駅スタ         8966
# 2020-12-19      22      18       1       0    1     味スタ        14373
# 2020-12-19       3      14       0       2    2      埼玉        19319
#
#                 HomeElo      AwayElo     HomeED     AwayED
# Date
# 2006-03-04  1500.000000  1500.000000   0.000000   0.000000
# 2006-03-05  1500.000000  1500.000000   0.000000   0.000000
# 2006-03-05  1500.000000  1500.000000   0.000000   0.000000
# 2006-03-05  1500.000000  1500.000000   0.000000   0.000000
# 2006-03-05  1500.000000  1500.000000   0.000000   0.000000
# ...                 ...          ...        ...        ...
# 2020-12-19  1594.223262  1560.240999   4.238372  -5.817036
# 2020-12-19  1514.711944  1524.417742   9.010605 -13.070625
# 2020-12-19  1453.298544  1457.903358  17.121750   7.296910
# 2020-12-19  1539.610108  1453.139153   8.225123   0.000000
# 2020-12-19  1485.202480  1458.324251 -18.510865   2.818543
#
# [4590 rows x 16 columns]

# %%
accuracies = []

def predict(year):
    df_past = pd.concat([df[f"{year-3}"],df[f"{year-2}"],df[f"{year-1}"]])
    X_train=df_past[["HomeElo","AwayElo","HomeED","AwayED"]].values
    y_train = df_past["W/L"].values
    
    df_future = df[f"{year}"]
    X_test = df_future[["HomeElo","AwayElo","HomeED","AwayED"]].values
    y_test = df_future["W/L"].values

    
    rf= RandomForestClassifier(max_depth=5)  
    rf.fit(X_train,y_train)
    y_pred = rf.predict(X_test)
   
    accuracy = rf.score(X_test,y_test) 
    accuracies.append(accuracy)

# %%
for _ in range(10):
    for y in (2013,2014,2015,2016,2017,2018,2019,2020):
        predict(y)

# %%
# 8シーズン×10回の精度の平均
np.mean(accuracies)
# Out:
# 0.46213235294117655

# %%
n, bins, patches=plt.hist(accuracies, bins=8)
plt.xlabel("Accuracy")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %% [markdown]
# ### 考察
#
# 以前まで外部サイトから取得していたeloratingとは違い今回は自分で算出したところ､精度が大きく下がった｡以前までの所得方法に誤りがあった可能性がある｡
# また､今後の拡張性も考慮して自分で算出したratingを用いる｡
#
# rating値しか使っていないので､ratingの大小で分類されやすく分類の精度が伸びていないのでは?と考えられる
