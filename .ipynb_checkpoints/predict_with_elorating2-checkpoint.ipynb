# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mglearn
from sklearn import svm
import datetime as dt
from sklearn.ensemble import RandomForestClassifier

# %%
df_all_years = pd.read_csv("./match_data_yearly/all_years.csv")
df_all_years["Date"] = pd.to_datetime(df_all_years["Date"])
df_all_years = df_all_years.set_index(df_all_years["Date"])

# %%
df_all_years.index
# Out:
# DatetimeIndex(['2006-03-04', '2006-03-05', '2006-03-05', '2006-03-05',
#                '2006-03-05', '2006-03-05', '2006-03-05', '2006-03-05',
#                '2006-03-05', '2006-03-11',
#                ...
#                '2020-12-16', '2020-12-19', '2020-12-19', '2020-12-19',
#                '2020-12-19', '2020-12-19', '2020-12-19', '2020-12-19',
#                '2020-12-19', '2020-12-19'],
#               dtype='datetime64[ns]', name='Date', length=4590, freq=None)

# %%
df_all_years['2010':'2012']
# Out:
#             Year  Sec       Date                 Home                 Away  \
# Date
# 2010-03-06  2010    1 2010-03-06         jubilo-iwata       vegalta-sendai
# 2010-03-06  2010    1 2010-03-06      shonan-bellmare    montedio-yamagata
# 2010-03-06  2010    1 2010-03-06             fc-tokyo  yokohama-fa-marinos
# 2010-03-06  2010    1 2010-03-06  sanfrecce-hiroshima      shimizu-s-pulse
# 2010-03-06  2010    1 2010-03-06    kawasaki-frontale      albirex-niigata
# ...          ...  ...        ...                  ...                  ...
# 2012-12-01  2012   34 2012-12-01      shimizu-s-pulse         omiya-ardija
# 2012-12-01  2012   34 2012-12-01         jubilo-iwata          gamba-osaka
# 2012-12-01  2012   34 2012-12-01         cerezo-osaka    kawasaki-frontale
# 2012-12-01  2012   34 2012-12-01          vissel-kobe  sanfrecce-hiroshima
# 2012-12-01  2012   34 2012-12-01      kashima-antlers       kashiwa-reysol
#
#             HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  Attendances
# Date
# 2010-03-06      13      54       0       1    2     ヤマハ        10440
# 2010-03-06      12      29       1       1    0      平塚        11280
# 2010-03-06      22       5       1       0    1     味スタ        29011
# 2010-03-06      10       7       1       1    0     広島ビ        16216
# 2010-03-06      21      78       2       1    1     等々力        22117
# ...            ...     ...     ...     ...  ...     ...          ...
# 2012-12-01       7      27       0       0    0    アウスタ        14729
# 2012-12-01      13       9       2       1    1     ヤマハ        14389
# 2012-12-01      20      21       2       2    0      長居        18487
# 2012-12-01      18      10       0       1    2    ホームズ        22224
# 2012-12-01       1      11       2       0    1     カシマ        19141
#
# [918 rows x 12 columns]

# %%
df_match_up=pd.get_dummies(df_all_years[["Home","Away"]])

# %%
df_all_years = pd.concat([df_all_years,df_match_up],axis=1)
df_all_years
# Out:
#             Year  Sec       Date                  Home                 Away  \
# Date
# 2006-03-04  2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 2006-03-05  2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 2006-03-05  2006    1 2006-03-05              fc-tokyo         oita-trinita
# 2006-03-05  2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 2006-03-05  2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...          ...  ...        ...                   ...                  ...
# 2020-12-19  2020   34 2020-12-19       kashima-antlers         cerezo-osaka
# 2020-12-19  2020   34 2020-12-19  nagoya-grampus-eight  sanfrecce-hiroshima
# 2020-12-19  2020   34 2020-12-19            sagan-tosu         oita-trinita
# 2020-12-19  2020   34 2020-12-19              fc-tokyo          vissel-kobe
# 2020-12-19  2020   34 2020-12-19    urawa-red-diamonds    consadole-sapporo
#
#             HomeID  AwayID  HomeGF  AwayGF  W/L  ... Away_shonan-bellmare  \
# Date                                             ...
# 2006-03-04       9       3       1       1    0  ...                    0
# 2006-03-05      28       7       0       2    2  ...                    0
# 2006-03-05      22      31       2       0    1  ...                    0
# 2006-03-05      13      23       1       1    0  ...                    0
# 2006-03-05       8      20       3       2    1  ...                    0
# ...            ...     ...     ...     ...  ...  ...                  ...
# 2020-12-19       1      20       1       1    0  ...                    0
# 2020-12-19       8      10       1       0    1  ...                    0
# 2020-12-19      33      31       2       2    0  ...                    0
# 2020-12-19      22      18       1       0    1  ...                    0
# 2020-12-19       3      14       0       2    2  ...                    0
#
#             Away_tokushima-vortis  Away_tokyo-verdy  Away_urawa-red-diamonds  \
# Date
# 2006-03-04                      0                 0                        1
# 2006-03-05                      0                 0                        0
# 2006-03-05                      0                 0                        0
# 2006-03-05                      0                 0                        0
# 2006-03-05                      0                 0                        0
# ...                           ...               ...                      ...
# 2020-12-19                      0                 0                        0
# 2020-12-19                      0                 0                        0
# 2020-12-19                      0                 0                        0
# 2020-12-19                      0                 0                        0
# 2020-12-19                      0                 0                        0
#
#             Away_v-varen-nagasaki  Away_vegalta-sendai  Away_ventforet-kofu  \
# Date
# 2006-03-04                      0                    0                    0
# 2006-03-05                      0                    0                    0
# 2006-03-05                      0                    0                    0
# 2006-03-05                      0                    0                    0
# 2006-03-05                      0                    0                    0
# ...                           ...                  ...                  ...
# 2020-12-19                      0                    0                    0
# 2020-12-19                      0                    0                    0
# 2020-12-19                      0                    0                    0
# 2020-12-19                      0                    0                    0
# 2020-12-19                      0                    0                    0
#
#             Away_vissel-kobe  Away_yokohama-fa-marinos  Away_yokohama-fc
# Date
# 2006-03-04                 0                         0                 0
# 2006-03-05                 0                         0                 0
# 2006-03-05                 0                         0                 0
# 2006-03-05                 0                         0                 0
# 2006-03-05                 0                         0                 0
# ...                      ...                       ...               ...
# 2020-12-19                 0                         0                 0
# 2020-12-19                 0                         0                 0
# 2020-12-19                 0                         0                 0
# 2020-12-19                 1                         0                 0
# 2020-12-19                 0                         0                 0
#
# [4590 rows x 72 columns]

# %%
# accuracies = []
# y_pred_probas = []

# df_elo =pd.read_csv("./elorating.csv")
# df_elo["date"] = pd.to_datetime(df_elo["date"])
# df_elo =  df_elo.set_index("date")

# def predict(year):
# #     df_past_1 = pd.read_csv(f'./match_data_yearly/{year-1}.csv')
# #     df_past_2 = pd.read_csv(f'./match_data_yearly/{year-2}.csv')
# #     df_past_3 = pd.read_csv(f'./match_data_yearly/{year-3}.csv')

# #     df_past = pd.concat([df_past_3,df_past_2,df_past_1]).reset_index(drop=True)    
# #     df_future = pd.read_csv(f'./match_data_yearly/{year}.csv').reset_index(drop=True) 
#     df_past = df_all_years[f"\'{year-3}\'":f"\'{year-1}\'"]
#     df_future = df_all_years[f"\'{year}\'"]
    
    
#     df_past.insert(12,'HomeElo',np.nan)
#     df_past.insert(13,'AwayElo',np.nan)
#     df_past.insert(14,'HomeED',np.nan)
#     df_past.insert(15,'AwayED',np.nan)
    
#     df_future.insert(12,'HomeElo',np.nan)
#     df_future.insert(13,'AwayElo',np.nan)
#     df_future.insert(14,'HomeED',np.nan)
#     df_future.insert(15,'AwayED',np.nan)
    
#     df_past["Date"] =  pd.to_datetime(df_past["Date"])
#     df_future["Date"] = pd.to_datetime(df_future["Date"])
    

#     for index,row in df_past.iterrows():
#         home_elo = df_elo.loc[row["Date"], row["Home"]]
#         away_elo = df_elo.loc[row["Date"], row["Away"]]    

#         df_past.at[index,"HomeElo"] = home_elo
#         df_past.at[index,"AwayElo"] = away_elo

#         home_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 1), row["Home"]]
#         away_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 1), row["Away"]]

#         df_past.at[index,"HomeED"] = home_elo - home_elo_1mago
#         df_past.at[index,"AwayED"] = away_elo - away_elo_1mago
        
#     for index,row in df_future.iterrows():
#         home_elo = df_elo.loc[row["Date"], row["Home"]]
#         away_elo = df_elo.loc[row["Date"], row["Away"]]    

#         df_future.at[index,"HomeElo"] = home_elo
#         df_future.at[index,"AwayElo"] = away_elo

#         home_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 1), row["Home"]]
#         away_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 1), row["Away"]]

#         df_future.at[index,"HomeED"] = home_elo - home_elo_1mago
#         df_future.at[index,"AwayED"] = away_elo - away_elo_1mago

#     X_train = df_past[["HomeElo","AwayElo","HomeED","AwayED"]].values
#     y_train = df_past["W/L"].values
#     X_test = df_future[["HomeElo","AwayElo","HomeED","AwayED"]].values
#     y_test = df_future["W/L"].values

#     rf= RandomForestClassifier(max_depth=5)  
#     rf.fit(X_train,y_train)
#     y_pred = rf.predict(X_test)
#     y_pred_proba=rf.predict_proba(X_test)
#     y_pred_probas.append(y_pred_proba) 
    
   
#     accuracy = rf.score(X_test,y_test) 
#     accuracies.append(accuracy)

# %%
# # 8シーズンを10回分予測
# for _ in range(5):
#     for y in (2013,2014,2015,2016,2017,2018,2019,2020):
#         predict(y)

# %%
# # 8シーズン×10回の精度の平均
# np.mean(accuracies)

# %%
# n, bins, patches=plt.hist(accuracies, bins=8)
# plt.xlabel("Accuracy")
# plt.ylabel("Frequency")
# plt.title("Histogram")
# plt.show()

# %%
year = 2020

df_past = df_all_years[f"\'{year-3}\'":f"\'{year-1}\'"]
df_future = df_all_years[f"\'{year}\'"]

df_past = pd.concat([df_past_3,df_past_2,df_past_1]).reset_index(drop=True)    
df_future = pd.read_csv(f'./match_data_yearly/{year}.csv').reset_index(drop=True)

# %%
df_past.insert(12,'HomeElo',np.nan)
df_past.insert(13,'AwayElo',np.nan)

df_past.insert(14,'HomeED',np.nan)
df_past.insert(15,'AwayED',np.nan)

# %%
df_future.insert(12,'HomeElo',np.nan)
df_future.insert(13,'AwayElo',np.nan)

df_future.insert(14,'HomeED',np.nan)
df_future.insert(15,'AwayED',np.nan)

# %%
df_past["Date"] =  pd.to_datetime(df_past["Date"])
df_future["Date"] = pd.to_datetime(df_future["Date"])

# %%
df_elo =pd.read_csv("./elorating.csv")
df_elo["date"] = pd.to_datetime(df_elo["date"])
df_elo =  df_elo.set_index("date")

# %%
for index,row in df_past.iterrows():
    home_elo = df_elo.loc[row["Date"], row["Home"]]
    away_elo = df_elo.loc[row["Date"], row["Away"]]    
    
    df_past.at[index,"HomeElo"] = home_elo
    df_past.at[index,"AwayElo"] = away_elo
    
    home_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 6), row["Home"]]
    away_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 6), row["Away"]]
    
    df_past.at[index,"HomeED"] = home_elo - home_elo_1mago
    df_past.at[index,"AwayED"] = away_elo - away_elo_1mago

# %%
df_past
# Out:
#      Year  Sec       Date                 Home                Away  HomeID  \
# 0    2017    1 2017-02-25  yokohama-fa-marinos  urawa-red-diamonds       5
# 1    2017    1 2017-02-25      shimizu-s-pulse         vissel-kobe       7
# 2    2017    1 2017-02-25      kashima-antlers            fc-tokyo       1
# 3    2017    1 2017-02-25       vegalta-sendai   consadole-sapporo      54
# 4    2017    1 2017-02-25  sanfrecce-hiroshima     albirex-niigata      10
# ..    ...  ...        ...                  ...                 ...     ...
# 913  2019   34 2019-12-07  yokohama-fa-marinos            fc-tokyo       5
# 914  2019   34 2019-12-07          vissel-kobe        jubilo-iwata      18
# 915  2019   34 2019-12-07         oita-trinita        cerezo-osaka      31
# 916  2019   34 2019-12-07   urawa-red-diamonds         gamba-osaka       3
# 917  2019   34 2019-12-07     matsumoto-yamaga     shonan-bellmare      46
#
#      AwayID  HomeGF  AwayGF  W/L Stadium  Attendances      HomeElo  \
# 0         3       3       2    1     日産ス        39284  1562.083853
# 1        18       0       1    2    アイスタ        17861  1406.460851
# 2        22       0       1    2     カシマ        28240  1569.261470
# 3        14       1       0    1    ユアスタ        17230  1455.642041
# 4        78       1       1    0     Ｅスタ        17545  1587.631135
# ..      ...     ...     ...  ...     ...          ...          ...
# 913      22       3       0    1     日産ス        63854  1581.137621
# 914      13       4       1    1    ノエスタ        25243  1493.859502
# 915      20       0       2    2    昭和電ド        17233  1432.201390
# 916       9       2       3    2      埼玉        47188  1491.737209
# 917      12       1       1    0    サンアル        16881  1387.152928
#
#          AwayElo     HomeED     AwayED
# 0    1662.061998  12.974607  17.439890
# 1    1524.134609   0.000000  42.073369
# 2    1559.881204 -38.153792  31.781411
# 3    1277.479362 -17.012660   0.000000
# 4    1414.450313 -15.933328 -27.882057
# ..           ...        ...        ...
# 913  1557.295148  39.211111  -5.142210
# 914  1442.637682  26.428726 -18.002841
# 915  1553.085215  21.491392  29.344918
# 916  1518.958249 -41.751846  21.561337
# 917  1422.686138  -4.755177 -15.142222
#
# [918 rows x 16 columns]

# %%
for index,row in df_future.iterrows():
    home_elo = df_elo.loc[row["Date"], row["Home"]]
    away_elo = df_elo.loc[row["Date"], row["Away"]]    
    
    df_future.at[index,"HomeElo"] = home_elo
    df_future.at[index,"AwayElo"] = away_elo
    
    home_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 6), row["Home"]]
    away_elo_1mago = df_elo.loc[row["Date"]- pd.tseries.offsets.DateOffset(months = 6), row["Away"]]
    
    df_future.at[index,"HomeED"] = home_elo - home_elo_1mago
    df_future.at[index,"AwayED"] = away_elo - away_elo_1mago

# %%
df_future
# Out:
#      Year  Sec       Date                  Home                  Away  HomeID  \
# 0    2020    1 2020-02-21       shonan-bellmare    urawa-red-diamonds      12
# 1    2020    1 2020-02-22        vegalta-sendai  nagoya-grampus-eight      54
# 2    2020    1 2020-02-22          cerezo-osaka          oita-trinita      20
# 3    2020    1 2020-02-22        kashiwa-reysol     consadole-sapporo      11
# 4    2020    1 2020-02-22     kawasaki-frontale            sagan-tosu      21
# ..    ...  ...        ...                   ...                   ...     ...
# 301  2020   34 2020-12-19       kashima-antlers          cerezo-osaka       1
# 302  2020   34 2020-12-19  nagoya-grampus-eight   sanfrecce-hiroshima       8
# 303  2020   34 2020-12-19            sagan-tosu          oita-trinita      33
# 304  2020   34 2020-12-19              fc-tokyo           vissel-kobe      22
# 305  2020   34 2020-12-19    urawa-red-diamonds     consadole-sapporo       3
#
#      AwayID  HomeGF  AwayGF  W/L Stadium  Attendances      HomeElo  \
# 0         3       2       3    2    ＢＭＷス        13071  1421.870796
# 1         8       1       1    0    ユアスタ        13968  1458.602016
# 2        31       1       0    1    ヤンマー        15535  1558.408896
# 3        14       4       2    1    三協Ｆ柏        12468  1502.754736
# 4        33       0       0    0     等々力        21117  1628.158694
# ..      ...     ...     ...  ...     ...          ...          ...
# 301      20       1       1    0     カシマ        11251  1594.223262
# 302      10       1       0    1     豊田ス        16825  1514.711944
# 303      31       2       2    0     駅スタ         8966  1453.298544
# 304      18       1       0    1     味スタ        14373  1539.610108
# 305      14       0       2    2      埼玉        19319  1485.202480
#
#          AwayElo     HomeED     AwayED
# 0    1484.362717 -20.500847 -38.900762
# 1    1430.661356  -5.201577 -36.403446
# 2    1426.877710  33.330940   4.150293
# 3    1481.201788   0.000000 -18.717029
# 4    1455.614582  -4.024025 -14.057401
# ..           ...        ...        ...
# 301  1560.240999  -0.357317  -3.276128
# 302  1524.417742  83.408614 -21.304442
# 303  1457.903358  -5.991688  36.133879
# 304  1453.139153 -16.034704 -43.642500
# 305  1458.324251  -5.736627 -15.373176
#
# [306 rows x 16 columns]

# %%
X_train = df_past[["HomeElo","AwayElo","HomeED","AwayED"]].values
y_train = df_past["W/L"].values

X_test = df_future[["HomeElo","AwayElo","HomeED","AwayED"]].values
y_test = df_future["W/L"].values

# %%
X_train.shape
# Out:
# (918, 4)

# %%
rf= RandomForestClassifier(max_depth=5)  
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
y_pred_proba=rf.predict_proba(X_test)

# %%
rf.score(X_test,y_test)
# Out:
# 0.4477124183006536

# %%
rf.feature_importances_
# Out:
# array([0.24529843, 0.30146383, 0.20509586, 0.24814187])

# %%
np.sum(y_pred_proba, axis=0)
# Out:
# array([ 71.87544647, 127.38587151, 106.73868202])

# %%
print(len(df_future[df_future["W/L"]==0]),len(df_future[df_future["W/L"]==1]),len(df_future[df_future["W/L"]==2]))
# Out:
# 68 118 120

# %% [markdown]
# ### 考察
#
# 以前まで外部サイトから取得していたeloratingとは違い今回は自分で算出したところ､精度が大きく下がった｡以前までの所得方法に誤りがあった可能性がある｡
# また､今後の拡張性も考慮して自分で算出したratingを用いる｡
#
# rating値しか使っていないので､ratingの大小で分類されやすく分類の精度が伸びていないのでは?と考えられる
