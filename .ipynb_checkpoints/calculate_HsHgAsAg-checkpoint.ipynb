# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
df = pd.read_csv("./match_data/shim/shim_2020.csv")

# %%
df
# Out:
#     Unnamed: 0   節         開催日   曜日    相手  スコア  得点  失点  H/A    会場  ...  \
# 0            0   1  2020-02-23  (日)  FC東京  1-3   1   3    0  アイスタ  ...
# 1            1   2  2020-07-04  (土)   名古屋  1-2   1   2    0  アイスタ  ...
# 2            2   3  2020-07-08  (水)   Ｃ大阪  0-2   0   2    1  ヤンマー  ...
# 3            3   4  2020-07-12  (日)   Ｇ大阪  1-2   1   2    0  アイスタ  ...
# 4            4   5  2020-07-18  (土)    神戸  1-3   1   3    1  ノエスタ  ...
# 5            5   6  2020-07-22  (水)    鳥栖  1-1   1   1    1   駅スタ  ...
# 6            6   7  2020-07-26  (日)    大分  4-2   4   2    0  アイスタ  ...
# 7            7   8  2020-08-01  (土)    浦和  1-1   1   1    1    埼玉  ...
# 8            8   9  2020-08-08  (土)    札幌  3-1   3   1    0  アイスタ  ...
# 9            9  10  2020-08-15  (土)    仙台  0-0   0   0    1  ユアスタ  ...
# 10          10  11  2020-08-19  (水)  横浜FM  3-4   3   4    0  アイスタ  ...
# 11          11  12  2020-08-22  (土)  横浜FC  2-3   2   3    0  アイスタ  ...
# 12          12  13  2020-08-29  (土)   川崎Ｆ  0-5   0   5    1   等々力  ...
# 13          13  14  2020-09-05  (土)     柏  1-2   1   2    0  アイスタ  ...
# 14          14  15  2020-09-09  (水)    広島  1-4   1   4    1   Ｅスタ  ...
# 15          15  16  2020-09-12  (土)    鹿島  1-2   1   2    0  アイスタ  ...
# 16          16  24  2020-09-16  (水)  横浜FM  0-3   0   3    1   日産ス  ...
# 17          17  17  2020-09-19  (土)    湘南  3-0   3   0    1  ＢＭＷス  ...
# 18          18  18  2020-09-23  (水)    浦和  1-2   1   2    0  アイスタ  ...
# 19          19  19  2020-09-26  (土)   名古屋  1-3   1   3    1   豊田ス  ...
# 20          20  20  2020-10-03  (土)    大分  1-2   1   2    1  昭和電ド  ...
# 21          21  21  2020-10-01  (土)    広島  2-3   2   3    0  アイスタ  ...
# 22          22  22  2020-10-14  (水)  FC東京  1-3   1   3    1   味スタ  ...
# 23          23  23  2020-10-18  (日)    鳥栖  1-1   1   1    0  アイスタ  ...
# 24          24  25  2020-10-31  (土)     柏  0-0   0   0    1  三協Ｆ柏  ...
# 25          25  26  2020-11-03  (火)    神戸  3-1   3   1    0  アイスタ  ...
# 26          26  27  2020-11-14  (土)   Ｃ大阪  3-1   3   1    0  アイスタ  ...
# 27          27  28  2020-11-21  (土)    札幌  1-5   1   5    1   札幌ド  ...
# 28          28  29  2020-11-25  (水)  横浜FC  3-1   3   1    1  ニッパツ  ...
# 29          29  30  2020-11-29  (日)    湘南  1-1   1   1    0  アイスタ  ...
# 30          30  31  2020-12-05  (土)   川崎Ｆ  2-2   2   2    0  アイスタ  ...
# 31          31  32  2020-12-12  (土)    鹿島  0-2   0   2    1   カシマ  ...
# 32          32  33  2020-12-16  (水)    仙台  2-3   2   3    0  アイスタ  ...
# 33          33  34  2020-12-19  (土)   Ｇ大阪  2-0   2   0    1  パナスタ  ...
#
#     チャンス構築率 シュート  シュート成功率    支配率  攻撃CBP  パスCBP     奪取P    守備P  \
# 0     0.136   16    0.063  0.599  16.52  13.85   94.04   9.09
# 1     0.094   10    0.100  0.553  19.15  16.70   59.89  12.75
# 2     0.113   11    0.000  0.444  15.04  10.96   82.72  13.50
# 3     0.195   22    0.045  0.595  19.27  15.33   83.50  11.45
# 4     0.106   10    0.100  0.476  16.17  14.21   83.52  13.03
# 5     0.141   13    0.077  0.442  14.63  12.57   50.93  17.93
# 6     0.182   22    0.182  0.530  17.90  16.10   98.02  11.51
# 7     0.095   11    0.091  0.579  21.71  16.67   87.77  13.94
# 8     0.204   22    0.136  0.494  18.80  15.14   68.82  12.74
# 9     0.109   14    0.000  0.553  18.58  16.50   64.62  14.46
# 10    0.137   17    0.118  0.479  13.93  10.28   61.70  20.39
# 11    0.184   19    0.105  0.442  16.91  15.00   86.25   9.00
# 12    0.075    8    0.000  0.481  12.07  10.07   56.65  20.95
# 13    0.123   14    0.071  0.556  18.06  12.91   82.08  11.94
# 14    0.129   15    0.067  0.566  16.23  12.63   82.46  15.26
# 15    0.085   11    0.091  0.523  13.04   9.67   70.51  13.04
# 16    0.052    6    0.000  0.363   7.82   6.19   77.75  31.32
# 17    0.162   18    0.167  0.548  18.56  13.82   71.38  17.04
# 18    0.138   15    0.067  0.571  22.28  18.12  111.92  12.17
# 19    0.116   11    0.091  0.459  14.92  13.00   59.22   9.48
# 20    0.082    8    0.125  0.504  13.75  11.92   85.41   9.54
# 21    0.118   14    0.143  0.580  19.31  14.59   98.10  11.94
# 22    0.087    9    0.111  0.562  18.55  15.07   73.68  10.80
# 23    0.039    4    0.250  0.394   7.83   7.31   48.01  20.79
# 24    0.114   14    0.000  0.531  15.99  13.30  109.87  14.22
# 25    0.150   17    0.176  0.431  16.05  12.81   84.36  13.90
# 26    0.174   19    0.158  0.439  15.56  12.71   92.57  17.06
# 27    0.139   15    0.067  0.503  16.86  13.99   63.90  15.23
# 28    0.103   11    0.273  0.382   9.72   8.11   83.44  18.85
# 29    0.128   15    0.067  0.570  25.04  20.86   98.66  13.16
# 30    0.136   15    0.133  0.373  13.29  10.71   71.71  18.28
# 31    0.089   11    0.000  0.534  16.38  12.74   91.04  13.99
# 32    0.076    9    0.222  0.625  17.01  14.76  113.79  15.03
# 33    0.105   12    0.167  0.396  10.43   9.13  104.66  22.77
#
#                                   得点者           指揮官
# 0                          ['ティーラシン']  ピーター　クラモフスキー
# 1                              ['金子']  ピーター　クラモフスキー
# 2                                ['']  ピーター　クラモフスキー
# 3                              ['立田']  ピーター　クラモフスキー
# 4                              ['西澤']  ピーター　クラモフスキー
# 5                           ['Ｃジュニオ']  ピーター　クラモフスキー
# 6   ['ファンソッコ', 'Ｃジュニオ', '立田', 'ヴァウド']  ピーター　クラモフスキー
# 7                            ['ヴァウド']  ピーター　クラモフスキー
# 8           ['金子', 'Ｒアウグスト', 'Ｃジュニオ']  ピーター　クラモフスキー
# 9                                ['']  ピーター　クラモフスキー
# 10                 ['西澤', '金井', 'OG']  ピーター　クラモフスキー
# 11                       ['金子', '竹内']  ピーター　クラモフスキー
# 12                               ['']  ピーター　クラモフスキー
# 13                          ['Ｃジュニオ']  ピーター　クラモフスキー
# 14                          ['Ｃジュニオ']  ピーター　クラモフスキー
# 15                         ['ティーラシン']  ピーター　クラモフスキー
# 16                               ['']  ピーター　クラモフスキー
# 17           ['Ｃジュニオ', 'Ｊドゥトラ', '西澤']  ピーター　クラモフスキー
# 18                         ['ティーラシン']  ピーター　クラモフスキー
# 19                          ['Ｃジュニオ']  ピーター　クラモフスキー
# 20                          ['Ｊドゥトラ']  ピーター　クラモフスキー
# 21                    ['Ｊドゥトラ', '後藤']  ピーター　クラモフスキー
# 22                          ['Ｊドゥトラ']  ピーター　クラモフスキー
# 23                           ['ヴァウド']  ピーター　クラモフスキー
# 24                               ['']  ピーター　クラモフスキー
# 25           ['ヴァウド', 'エウシーニョ', '金井']         平岡　宏章
# 26          ['Ｒアウグスト', '中村', 'Ｃジュニオ']         平岡　宏章
# 27                         ['ファンソッコ']         平岡　宏章
# 28              ['金子', 'Ｊドゥトラ', '竹内']         平岡　宏章
# 29                          ['Ｃジュニオ']         平岡　宏章
# 30                ['Ｃジュニオ', 'Ｒアウグスト']         平岡　宏章
# 31                               ['']         平岡　宏章
# 32                    ['西澤', 'Ｊドゥトラ']         平岡　宏章
# 33                       ['川本', '金子']         平岡　宏章
#
# [34 rows x 24 columns]

# %%
df.mean()
# Out:
# Unnamed: 0      16.500000
# 節               17.500000
# 得点               1.411765
# 失点               2.058824
# H/A              0.500000
# 観客数           5106.411765
# AGI             49.882353
# KAGI            45.676471
# チャンス構築率          0.121059
# シュート            13.470588
# シュート成功率          0.101853
# 支配率              0.502265
# 攻撃CBP           16.098824
# パスCBP           13.168529
# 奪取P             80.969118
# 守備P             14.898529
# dtype: float64

# %%
df[df["H/A"]==0].mean()
# Out:
# Unnamed: 0      15.941176
# 節               16.764706
# 得点               1.882353
# 失点               2.058824
# H/A              0.000000
# 観客数           5235.411765
# AGI             52.588235
# KAGI            47.647059
# チャンス構築率          0.135235
# シュート            15.352941
# シュート成功率          0.125118
# 支配率              0.514941
# 攻撃CBP           17.055882
# パスCBP           13.932353
# 奪取P             83.760588
# 守備P             13.778824
# dtype: float64

# %%
df[df["H/A"]==1].mean()
# Out:
# Unnamed: 0      17.058824
# 節               18.235294
# 得点               0.941176
# 失点               2.058824
# H/A              1.000000
# 観客数           4977.411765
# AGI             47.176471
# KAGI            43.705882
# チャンス構築率          0.106882
# シュート            11.588235
# シュート成功率          0.078588
# 支配率              0.489588
# 攻撃CBP           15.141765
# パスCBP           12.404706
# 奪取P             78.177647
# 守備P             16.018235
# dtype: float64

# %%
dfH_train = df[(df["H/A"]==0) & (df["節"] <= 25) ].mean()

# %%
Hs = dfH_train["得点"]

# %%
Hs
# Out:
# 1.75

# %%
Hg = dfH_train["失点"]

# %%
Hg
# Out:
# 2.25

# %%
dfA_train = df[(df["H/A"]==1) & (df["節"] <= 25) ].mean()

# %%
dfA_train
# Out:
# Unnamed: 0      13.153846
# 節               14.384615
# 得点               0.769231
# 失点               2.076923
# H/A              1.000000
# 観客数           4082.461538
# AGI             47.384615
# KAGI            43.384615
# チャンス構築率          0.106231
# シュート            11.384615
# シュート成功率          0.063769
# 支配率              0.500615
# 攻撃CBP           15.693846
# パスCBP           12.839231
# 奪取P             75.844615
# 守備P             15.497692
# dtype: float64

# %%
As = dfA_train["得点"]

# %%
Ag = dfA_train["失点"]

# %%
Ag
# Out:
# 2.076923076923077

# %%
with open('./match_data/results_1to25.csv', 'a') as f:
    writer = csv.writer(f)
    writer.writerow([team_id, Hs, Hg, As, Ag])
