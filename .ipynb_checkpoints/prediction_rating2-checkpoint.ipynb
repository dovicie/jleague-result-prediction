# %%
import re
import csv
import os
import glob
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import log_loss

# %%
df_match = pd.read_csv("./match_data_yearly/all_years.csv",index_col=0)
df_match["Date"] = pd.to_datetime(df_match["Date"])
df_match
# Out:
#           Year  Sec       Date                  Home                 Away  \
# ID
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6012807   2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 6012231   2006    1 2006-03-05              fc-tokyo         oita-trinita
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...        ...  ...        ...                   ...                  ...
# 20340120  2020   34 2020-12-19       kashima-antlers         cerezo-osaka
# 20340810  2020   34 2020-12-19  nagoya-grampus-eight  sanfrecce-hiroshima
# 20343331  2020   34 2020-12-19            sagan-tosu         oita-trinita
# 20342218  2020   34 2020-12-19              fc-tokyo          vissel-kobe
# 20340314  2020   34 2020-12-19    urawa-red-diamonds    consadole-sapporo
#
#           HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  Attendances
# ID
# 6010903        9       3       1       1    0      万博        20916
# 6012807       28       7       0       2    2      小瀬        14277
# 6012231       22      31       2       0    1     味スタ        22531
# 6011323       13      23       1       1    0      静岡        28564
# 6010820        8      20       3       2    1     瑞穂陸        17199
# ...          ...     ...     ...     ...  ...     ...          ...
# 20340120       1      20       1       1    0     カシマ        11251
# 20340810       8      10       1       0    1     豊田ス        16825
# 20343331      33      31       2       2    0     駅スタ         8966
# 20342218      22      18       1       0    1     味スタ        14373
# 20340314       3      14       0       2    2      埼玉        19319
#
# [4590 rows x 12 columns]

# %%
df_rate_all = pd.DataFrame(index=df_match.index, columns=["Date","Sec","HomeRate","AwayRate","W/L"])
df_rate_all["W/L"] = df_match["W/L"]
df_rate_all["Sec"] = df_match["Sec"]
df_rate_all["Date"] = df_match["Date"]
df_rate_all
# Out:
#                Date  Sec HomeRate AwayRate  W/L
# ID
# 6010903  2006-03-04    1      NaN      NaN    0
# 6012807  2006-03-05    1      NaN      NaN    2
# 6012231  2006-03-05    1      NaN      NaN    1
# 6011323  2006-03-05    1      NaN      NaN    0
# 6010820  2006-03-05    1      NaN      NaN    1
# ...             ...  ...      ...      ...  ...
# 20340120 2020-12-19   34      NaN      NaN    0
# 20340810 2020-12-19   34      NaN      NaN    1
# 20343331 2020-12-19   34      NaN      NaN    0
# 20342218 2020-12-19   34      NaN      NaN    1
# 20340314 2020-12-19   34      NaN      NaN    2
#
# [4590 rows x 5 columns]

# %%
df_rate_csv = pd.read_csv("./rating/all_years.csv", index_col=0,parse_dates=True)
df_rate_csv
# Out:
#             kashima-antlers  urawa-red-diamonds  yokohama-fa-marinos  \
# 2006-03-04             1500                1500                 1500
# 2006-03-05             1500                1500                 1500
# 2006-03-06             1508                1500                 1508
# 2006-03-07             1508                1500                 1508
# 2006-03-08             1508                1500                 1508
# ...                     ...                 ...                  ...
# 2020-12-16             1595                1490                 1543
# 2020-12-17             1595                1486                 1543
# 2020-12-18             1595                1486                 1543
# 2020-12-19             1595                1486                 1543
# 2020-12-20             1594                1478                 1532
#
#             kawasaki-frontale  sanfrecce-hiroshima  vegalta-sendai  \
# 2006-03-04               1500                 1500            1350
# 2006-03-05               1500                 1500            1350
# 2006-03-06               1508                 1492            1350
# 2006-03-07               1508                 1492            1350
# 2006-03-08               1508                 1492            1350
# ...                       ...                  ...             ...
# 2020-12-16               1678                 1535            1411
# 2020-12-17               1682                 1526            1419
# 2020-12-18               1682                 1526            1419
# 2020-12-19               1682                 1526            1419
# 2020-12-20               1686                 1517            1419
#
#             kashiwa-reysol  fc-tokyo  sagan-tosu  gamba-osaka  ...  \
# 2006-03-04            1350      1500        1350         1500  ...
# 2006-03-05            1350      1500        1350         1500  ...
# 2006-03-06            1350      1508        1350         1500  ...
# 2006-03-07            1350      1508        1350         1500  ...
# 2006-03-08            1351      1508        1350         1500  ...
# ...                    ...       ...         ...          ...  ...
# 2020-12-16            1478      1541        1444         1577  ...
# 2020-12-17            1487      1541        1455         1582  ...
# 2020-12-18            1487      1541        1455         1582  ...
# 2020-12-19            1487      1541        1455         1582  ...
# 2020-12-20            1483      1547        1455         1570  ...
#
#             omiya-ardija  avispa-fukuoka  matsumoto-yamaga  oita-trinita  \
# 2006-03-04          1500            1500              1350          1500
# 2006-03-05          1500            1500              1350          1500
# 2006-03-06          1508            1500              1350          1492
# 2006-03-07          1508            1500              1350          1492
# 2006-03-08          1508            1500              1350          1492
# ...                  ...             ...               ...           ...
# 2020-12-16          1420            1331              1424          1473
# 2020-12-17          1420            1331              1424          1480
# 2020-12-18          1420            1331              1424          1480
# 2020-12-19          1420            1331              1424          1480
# 2020-12-20          1420            1331              1424          1479
#
#             jef-united  tokyo-verdy  kyoto-sanga  tokushima-vortis  \
# 2006-03-04        1500         1350         1500              1350
# 2006-03-05        1500         1350         1500              1350
# 2006-03-06        1492         1350         1492              1350
# 2006-03-07        1492         1350         1492              1350
# 2006-03-08        1492         1350         1492              1350
# ...                ...          ...          ...               ...
# 2020-12-16        1410         1408         1362              1313
# 2020-12-17        1410         1408         1362              1313
# 2020-12-18        1410         1408         1362              1313
# 2020-12-19        1410         1408         1362              1313
# 2020-12-20        1410         1408         1362              1313
#
#             yokohama-fc  montedio-yamagata
# 2006-03-04         1350               1350
# 2006-03-05         1350               1350
# 2006-03-06         1350               1350
# 2006-03-07         1350               1350
# 2006-03-08         1351               1350
# ...                 ...                ...
# 2020-12-16         1406               1372
# 2020-12-17         1402               1372
# 2020-12-18         1402               1372
# 2020-12-19         1402               1372
# 2020-12-20         1413               1372
#
# [4157 rows x 30 columns]

# %%
df_rate_csv.index
# Out:
# DatetimeIndex(['2006-03-04', '2006-03-05', '2006-03-06', '2006-03-07',
#                '2006-03-08', '2006-03-09', '2006-03-10', '2006-03-11',
#                '2006-03-12', '2006-03-13',
#                ...
#                '2020-12-11', '2020-12-12', '2020-12-13', '2020-12-14',
#                '2020-12-15', '2020-12-16', '2020-12-17', '2020-12-18',
#                '2020-12-19', '2020-12-20'],
#               dtype='datetime64[ns]', length=4157, freq=None)

# %%
df_rate_csv.columns
# Out:
# Index(['kashima-antlers', 'urawa-red-diamonds', 'yokohama-fa-marinos',
#        'kawasaki-frontale', 'sanfrecce-hiroshima', 'vegalta-sendai',
#        'kashiwa-reysol', 'fc-tokyo', 'sagan-tosu', 'gamba-osaka',
#        'vissel-kobe', 'jubilo-iwata', 'consadole-sapporo', 'shimizu-s-pulse',
#        'cerezo-osaka', 'shonan-bellmare', 'v-varen-nagasaki',
#        'nagoya-grampus-eight', 'albirex-niigata', 'ventforet-kofu',
#        'omiya-ardija', 'avispa-fukuoka', 'matsumoto-yamaga', 'oita-trinita',
#        'jef-united', 'tokyo-verdy', 'kyoto-sanga', 'tokushima-vortis',
#        'yokohama-fc', 'montedio-yamagata'],
#       dtype='object')

# %%
df_rate_csv.plot(figsize=(6,4),legend=False)
# Out:
# <AxesSubplot:>

# %%
### 予稿用
df_rate_csv[[
    'gamba-osaka','kawasaki-frontale','consadole-sapporo','shimizu-s-pulse'
]].plot(figsize=(6,3),color=["blue","skyblue","red","orange"]).legend(loc='lower left')

# %%
j12020 = pd.read_csv("./clubs.csv",index_col=0).iloc[-1].values
j12020
# Out:
# array(['kashima-antlers', 'urawa-red-diamonds', 'yokohama-fa-marinos',
#        'kawasaki-frontale', 'sanfrecce-hiroshima', 'vegalta-sendai',
#        'fc-tokyo', 'sagan-tosu', 'gamba-osaka', 'vissel-kobe',
#        'consadole-sapporo', 'shimizu-s-pulse', 'cerezo-osaka',
#        'shonan-bellmare', 'nagoya-grampus-eight', 'oita-trinita',
#        'kashiwa-reysol', 'yokohama-fc'], dtype=object)

# %%
###PR用
df_rate_csv[[
    'kashima-antlers', 'kawasaki-frontale', 'gamba-osaka',
    'consadole-sapporo', 'shimizu-s-pulse', 'shonan-bellmare'
]].plot(figsize=(9,5),color=["#B8193F","#30B7FE","#083287","#EE0000","#FA870A","#51AE1B"]).legend(loc='lower left')

# %%
for index,row in df_match.iterrows():
    home_rate = df_rate_csv.loc[row["Date"], row["Home"]]
    away_rate = df_rate_csv.loc[row["Date"], row["Away"]]
    
    df_rate_all.at[index,"HomeRate"] = home_rate
    df_rate_all.at[index,"AwayRate"] = away_rate

# %%
df_rate_all["RateDiff"] = df_rate_all["HomeRate"] - df_rate_all["AwayRate"]

# %%
df_rate_all
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff
# ID
# 6010903  2006-03-04    1     1500     1500    0        0
# 6012807  2006-03-05    1     1500     1500    2        0
# 6012231  2006-03-05    1     1500     1500    1        0
# 6011323  2006-03-05    1     1500     1500    0        0
# 6010820  2006-03-05    1     1500     1500    1        0
# ...             ...  ...      ...      ...  ...      ...
# 20340120 2020-12-19   34     1595     1559    0       36
# 20340810 2020-12-19   34     1514     1526    1      -12
# 20343331 2020-12-19   34     1455     1480    0      -25
# 20342218 2020-12-19   34     1541     1454    1       87
# 20340314 2020-12-19   34     1486     1466    2       20
#
# [4590 rows x 6 columns]

# %%
df_rate_0614 = df_rate_all[df_rate_all["Date"].dt.year < 2015]
df_rate_0614
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff
# ID
# 6010903  2006-03-04    1     1500     1500    0        0
# 6012807  2006-03-05    1     1500     1500    2        0
# 6012231  2006-03-05    1     1500     1500    1        0
# 6011323  2006-03-05    1     1500     1500    0        0
# 6010820  2006-03-05    1     1500     1500    1        0
# ...             ...  ...      ...      ...  ...      ...
# 14342205 2014-12-06   34     1509     1553    0      -44
# 14340308 2014-12-06   34     1573     1521    2       52
# 14343609 2014-12-06   34     1309     1516    0     -207
# 14341054 2014-12-06   34     1543     1488    1       55
# 14347811 2014-12-08   34     1502     1564    2      -62
#
# [2754 rows x 6 columns]

# %% [markdown]
# ### レーティングと勝敗結果の関係性

# %%
hist2, bins = np.histogram(df_rate_0614[df_rate_0614["W/L"] == 2]["RateDiff"], range=(-310,310),bins=31)

# %%
hist1,bins =np.histogram(df_rate_0614[df_rate_0614["W/L"] == 1]["RateDiff"], range=(-310,310),bins=31)

# %%
hist0,bins = np.histogram(df_rate_0614[df_rate_0614["W/L"] == 0]["RateDiff"], range=(-310,310),bins=31)

# %%
df_hist = pd.DataFrame(index=[ int(b+10) for b in bins][:-1])
df_hist[1] = hist1
df_hist[0] = hist0
df_hist[2] = hist2

df_hist
# Out:
#         1   0   2
# -300    2   0   0
# -280    0   0   1
# -260    1   0   2
# -240    2   2   3
# -220    1   2   9
# -200    3   5  15
# -180   10   7  12
# -160    7  14  28
# -140   21  11  33
# -120   33  28  44
# -100   52  24  74
# -80    45  33  62
# -60    71  44  82
# -40    86  57  67
# -20   104  51  91
#  0    125  68  94
#  20   105  57  66
#  40   113  57  60
#  60    88  47  54
#  80    79  41  36
#  100   67  35  26
#  120   53  32  25
#  140   41  17   6
#  160   26   7   6
#  180   30  10   3
#  200   11   1   1
#  220   13   1   1
#  240    8   0   1
#  260    3   0   0
#  280    1   0   0
#  300    0   0   0

# %%
cross = pd.DataFrame(columns=[1,0,2])

# %%
for index,row in df_hist.iterrows():
    cross.loc[index] = (row/sum(row))

# %%
cross
# Out:
#              1         0         2
# -300  1.000000  0.000000  0.000000
# -280  0.000000  0.000000  1.000000
# -260  0.333333  0.000000  0.666667
# -240  0.285714  0.285714  0.428571
# -220  0.083333  0.166667  0.750000
# -200  0.130435  0.217391  0.652174
# -180  0.344828  0.241379  0.413793
# -160  0.142857  0.285714  0.571429
# -140  0.323077  0.169231  0.507692
# -120  0.314286  0.266667  0.419048
# -100  0.346667  0.160000  0.493333
# -80   0.321429  0.235714  0.442857
# -60   0.360406  0.223350  0.416244
# -40   0.409524  0.271429  0.319048
# -20   0.422764  0.207317  0.369919
#  0    0.435540  0.236934  0.327526
#  20   0.460526  0.250000  0.289474
#  40   0.491304  0.247826  0.260870
#  60   0.465608  0.248677  0.285714
#  80   0.506410  0.262821  0.230769
#  100  0.523438  0.273438  0.203125
#  120  0.481818  0.290909  0.227273
#  140  0.640625  0.265625  0.093750
#  160  0.666667  0.179487  0.153846
#  180  0.697674  0.232558  0.069767
#  200  0.846154  0.076923  0.076923
#  220  0.866667  0.066667  0.066667
#  240  0.888889  0.000000  0.111111
#  260  1.000000  0.000000  0.000000
#  280  1.000000  0.000000  0.000000
#  300       NaN       NaN       NaN

# %%
fig, ax = plt.subplots(figsize=(9,6))
ax.stackplot(cross.index,cross[1],cross[0],cross[2],labels=["Win","Draw","Loss"],colors=["#f00","#aaa","#00f"])
ax.legend(loc='lower right', bbox_to_anchor=(0.95, 0.05))
ax.set_xlabel("Rate difference")
ax.set_ylabel("Probability")
plt.title("Rating difference and W/L between 2006 and 2014")
plt.show()

# %%
### プロジェクトレポート用

fig, ax = plt.subplots(figsize=(6,4))
ax.stackplot(cross.index,cross[1],cross[0],cross[2],labels=["Win","Draw","Loss"],colors=["#f00","#aaa","#00f"])
ax.legend(loc='lower right', bbox_to_anchor=(0.95, 0.05))
ax.set_xlabel("Rating difference", fontsize=12)
ax.set_ylabel("Match result percentage", fontsize=12)
plt.show()

# %%
np.histogram(df_rate_0614["RateDiff"], range=(-100,100),bins=20)
# Out:
# (array([ 79,  67,  73,  84, 113, 114,  96, 128, 118, 122, 165, 118, 110,
#         127, 103, 110,  79,  81,  75,  70]),
#  array([-100.0, -90.0, -80.0, -70.0, -60.0, -50.0, -40.0, -30.0, -20.0,
#         -10.0, 0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0,
#         100.0], dtype=object))

# %%
122+165+118+118
# Out:
# 523

# %%
523/2754
# Out:
# 0.18990559186637618

# %% [markdown]
# レート差±20が全体の19.0%を占める

# %% [markdown]
# ### 実際に予測してみる

# %%
df_rate_1520 = df_rate_all[df_rate_all["Date"].dt.year >= 2015]
df_rate_1520
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff
# ID
# 15010846 2015-03-07    1     1531     1404    0      127
# 15010922 2015-03-07    1     1512     1510    0        2
# 15011028 2015-03-07    1     1550     1472    1       78
# 15013378 2015-03-07    1     1533     1495    1       38
# 15015429 2015-03-07    1     1482     1404    1       78
# ...             ...  ...      ...      ...  ...      ...
# 20340120 2020-12-19   34     1595     1559    0       36
# 20340810 2020-12-19   34     1514     1526    1      -12
# 20343331 2020-12-19   34     1455     1480    0      -25
# 20342218 2020-12-19   34     1541     1454    1       87
# 20340314 2020-12-19   34     1486     1466    2       20
#
# [1836 rows x 6 columns]

# %%
df_rate_1520["W/L"].value_counts()
# Out:
# 1    735
# 2    674
# 0    427
# Name: W/L, dtype: int64

# %%
df_rate_1520_pred = df_rate_1520.assign(Prediction=np.nan)
df_rate_1520_pred
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff  Prediction
# ID
# 15010846 2015-03-07    1     1531     1404    0      127         NaN
# 15010922 2015-03-07    1     1512     1510    0        2         NaN
# 15011028 2015-03-07    1     1550     1472    1       78         NaN
# 15013378 2015-03-07    1     1533     1495    1       38         NaN
# 15015429 2015-03-07    1     1482     1404    1       78         NaN
# ...             ...  ...      ...      ...  ...      ...         ...
# 20340120 2020-12-19   34     1595     1559    0       36         NaN
# 20340810 2020-12-19   34     1514     1526    1      -12         NaN
# 20343331 2020-12-19   34     1455     1480    0      -25         NaN
# 20342218 2020-12-19   34     1541     1454    1       87         NaN
# 20340314 2020-12-19   34     1486     1466    2       20         NaN
#
# [1836 rows x 7 columns]

# %%
for index,row in df_rate_1520_pred.iterrows():
    if row["RateDiff"] > 0:
        pred = 1
    elif row["RateDiff"] < 0:
        pred = 2
    else:
        pred = 0
    df_rate_1520_pred.at[index,"Prediction"] = pred
    
df_rate_1520_pred["Prediction"] = df_rate_1520_pred["Prediction"].astype(int)

# %%
df_rate_1520_pred["Prediction"].value_counts()
# Out:
# 1    921
# 2    905
# 0     10
# Name: Prediction, dtype: int64

# %%
df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction"]]["Prediction"].value_counts()
# Out:
# 1    454
# 2    411
# 0      2
# Name: Prediction, dtype: int64

# %%
df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction"]]["Prediction"].value_counts()/df_rate_1520_pred["W/L"].value_counts()
# Out:
# 1    0.617687
# 2    0.609792
# 0    0.004684
# dtype: float64

# %%
len(df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction"]])/len(df_rate_1520_pred)
# Out:
# 0.4722222222222222

# %%
accuracy_by_sec = df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction"]]["Sec"].value_counts().sort_index() / df_rate_1520_pred["Sec"].value_counts().sort_index()

# %%
x = accuracy_by_sec.index
y = np.poly1d(np.polyfit(accuracy_by_sec.index, accuracy_by_sec.values, 2))(accuracy_by_sec.index)

# %%
plt.plot(x, accuracy_by_sec.values, c="blue",marker="o",alpha=0.5)
plt.plot(x, y, c="red")
plt.title("Accuracy by section")
plt.xlabel("Section")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

# %%
## 予稿用
plt.plot(x, accuracy_by_sec.values, c="blue",marker="o",alpha=0.5)
plt.plot(x, y, c="red")
plt.title("Method 2",fontsize=18)
plt.xlabel("Section", fontsize=16)
plt.ylabel("Accuracy",fontsize=16)
plt.grid(True)
plt.show()

# %%
## PR用
plt.subplots(figsize=(4,3))
plt.plot(x, accuracy_by_sec.values, c="blue",marker="o",alpha=0.5 )
plt.plot(x, y, c="red")
plt.title("Method2.1",fontsize=14)
plt.xlabel("Section", fontsize=12)
plt.ylabel("Accuracy",fontsize=12)
plt.grid(True)

# %% [markdown]
# ### ±20を引き分けとみなす

# %%
df_rate_1520_pred = df_rate_1520_pred.assign(Prediction2=np.nan)
df_rate_1520_pred
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff  Prediction  \
# ID
# 15010846 2015-03-07    1     1531     1404    0      127           1
# 15010922 2015-03-07    1     1512     1510    0        2           1
# 15011028 2015-03-07    1     1550     1472    1       78           1
# 15013378 2015-03-07    1     1533     1495    1       38           1
# 15015429 2015-03-07    1     1482     1404    1       78           1
# ...             ...  ...      ...      ...  ...      ...         ...
# 20340120 2020-12-19   34     1595     1559    0       36           1
# 20340810 2020-12-19   34     1514     1526    1      -12           2
# 20343331 2020-12-19   34     1455     1480    0      -25           2
# 20342218 2020-12-19   34     1541     1454    1       87           1
# 20340314 2020-12-19   34     1486     1466    2       20           1
#
#           Prediction2
# ID
# 15010846          NaN
# 15010922          NaN
# 15011028          NaN
# 15013378          NaN
# 15015429          NaN
# ...               ...
# 20340120          NaN
# 20340810          NaN
# 20343331          NaN
# 20342218          NaN
# 20340314          NaN
#
# [1836 rows x 8 columns]

# %%
for index,row in df_rate_1520_pred.iterrows():
    if row["RateDiff"] > 20:
        pred = 1
    elif row["RateDiff"] < -20:
        pred = 2
    else:
        pred = 0
    df_rate_1520_pred.at[index,"Prediction2"] = pred
    
df_rate_1520_pred["Prediction2"] = df_rate_1520_pred["Prediction2"].astype(int)

# %%
df_rate_1520_pred
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff  Prediction  \
# ID
# 15010846 2015-03-07    1     1531     1404    0      127           1
# 15010922 2015-03-07    1     1512     1510    0        2           1
# 15011028 2015-03-07    1     1550     1472    1       78           1
# 15013378 2015-03-07    1     1533     1495    1       38           1
# 15015429 2015-03-07    1     1482     1404    1       78           1
# ...             ...  ...      ...      ...  ...      ...         ...
# 20340120 2020-12-19   34     1595     1559    0       36           1
# 20340810 2020-12-19   34     1514     1526    1      -12           2
# 20343331 2020-12-19   34     1455     1480    0      -25           2
# 20342218 2020-12-19   34     1541     1454    1       87           1
# 20340314 2020-12-19   34     1486     1466    2       20           1
#
#           Prediction2
# ID
# 15010846            1
# 15010922            0
# 15011028            1
# 15013378            1
# 15015429            1
# ...               ...
# 20340120            1
# 20340810            0
# 20343331            2
# 20342218            1
# 20340314            0
#
# [1836 rows x 8 columns]

# %%
df_rate_1520_pred["Prediction2"].value_counts()
# Out:
# 1    776
# 2    757
# 0    303
# Name: Prediction2, dtype: int64

# %%
df_rate_1520_pred[df_rate_1520_pred["W/L"]==df_rate_1520_pred["Prediction2"]]["Prediction2"].value_counts()
# Out:
# 1    403
# 2    359
# 0     75
# Name: Prediction2, dtype: int64

# %%
df_rate_1520_pred[df_rate_1520_pred["W/L"]==df_rate_1520_pred["Prediction2"]]["Prediction2"].value_counts()/df_rate_1520_pred["W/L"].value_counts()
# Out:
# 1    0.548299
# 2    0.532641
# 0    0.175644
# dtype: float64

# %%
len(df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction2"]])/len(df_rate_1520_pred)
# Out:
# 0.45588235294117646

# %%
len(df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction2"]])
# Out:
# 837

# %%
accuracy_by_sec = df_rate_1520_pred[df_rate_1520_pred["W/L"] == df_rate_1520_pred["Prediction2"]]["Sec"].value_counts().sort_index() / df_rate_1520_pred["Sec"].value_counts().sort_index()

# %%
x = accuracy_by_sec.index
y = np.poly1d(np.polyfit(accuracy_by_sec.index, accuracy_by_sec.values, 2))(accuracy_by_sec.index)

# %%
plt.plot(x, accuracy_by_sec.values, c="blue", marker="o",alpha=0.5)
plt.plot(x, y, c="red")
plt.title("Accuracy by section")
plt.xlabel("Section")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

# %%
## PR用
plt.subplots(figsize=(4,3))
plt.plot(x, accuracy_by_sec.values, c="blue",marker="o",alpha=0.5 )
plt.plot(x, y, c="red")
plt.title("Method2.2",fontsize=14)
plt.xlabel("Section", fontsize=12)
plt.ylabel("Accuracy",fontsize=12)
plt.grid(True)

# %% [markdown]
# ### イロレーティングを勝率換算して,Loglossを算出する
#
# 06-14年のレート差と勝敗関係からほぼどのレート差においても一定の引き分け試合が存在している.そこで06-14年の引き分け試合の割合が23.6%であることから,全試合に23.6%の確率があるとみなし,15-20年の勝率を換算する

# %%
df_rate_1520_pred
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff  Prediction  \
# ID
# 15010846 2015-03-07    1     1531     1404    0      127           1
# 15010922 2015-03-07    1     1512     1510    0        2           1
# 15011028 2015-03-07    1     1550     1472    1       78           1
# 15013378 2015-03-07    1     1533     1495    1       38           1
# 15015429 2015-03-07    1     1482     1404    1       78           1
# ...             ...  ...      ...      ...  ...      ...         ...
# 20340120 2020-12-19   34     1595     1559    0       36           1
# 20340810 2020-12-19   34     1514     1526    1      -12           2
# 20343331 2020-12-19   34     1455     1480    0      -25           2
# 20342218 2020-12-19   34     1541     1454    1       87           1
# 20340314 2020-12-19   34     1486     1466    2       20           1
#
#           Prediction2
# ID
# 15010846            1
# 15010922            0
# 15011028            1
# 15013378            1
# 15015429            1
# ...               ...
# 20340120            1
# 20340810            0
# 20343331            2
# 20342218            1
# 20340314            0
#
# [1836 rows x 8 columns]

# %%
df_rate_1520_pred.insert(8,"WinProba", np.nan)
df_rate_1520_pred.insert(9,"DrawProba", np.nan)
df_rate_1520_pred.insert(10,"LossProba", np.nan)

# %%
df_rate_1520_pred
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff  Prediction  \
# ID
# 15010846 2015-03-07    1     1531     1404    0      127           1
# 15010922 2015-03-07    1     1512     1510    0        2           1
# 15011028 2015-03-07    1     1550     1472    1       78           1
# 15013378 2015-03-07    1     1533     1495    1       38           1
# 15015429 2015-03-07    1     1482     1404    1       78           1
# ...             ...  ...      ...      ...  ...      ...         ...
# 20340120 2020-12-19   34     1595     1559    0       36           1
# 20340810 2020-12-19   34     1514     1526    1      -12           2
# 20343331 2020-12-19   34     1455     1480    0      -25           2
# 20342218 2020-12-19   34     1541     1454    1       87           1
# 20340314 2020-12-19   34     1486     1466    2       20           1
#
#           Prediction2  WinProba  DrawProba  LossProba
# ID
# 15010846            1       NaN        NaN        NaN
# 15010922            0       NaN        NaN        NaN
# 15011028            1       NaN        NaN        NaN
# 15013378            1       NaN        NaN        NaN
# 15015429            1       NaN        NaN        NaN
# ...               ...       ...        ...        ...
# 20340120            1       NaN        NaN        NaN
# 20340810            0       NaN        NaN        NaN
# 20343331            2       NaN        NaN        NaN
# 20342218            1       NaN        NaN        NaN
# 20340314            0       NaN        NaN        NaN
#
# [1836 rows x 11 columns]

# %%
for index,row in df_rate_1520_pred.iterrows():
    
    win_proba = 1 /(1+pow(10, row["RateDiff"]*(-1)/400) )*0.764
    loss_proba = 1/ (1+pow(10, row["RateDiff"]/400) )*0.764
    draw_proba = 0.236
    
    df_rate_1520_pred.at[index,"WinProba"] = win_proba
    df_rate_1520_pred.at[index,"LossProba"] = loss_proba
    df_rate_1520_pred.at[index,"DrawProba"] = draw_proba

# %%
df_rate_1520_pred
# Out:
#                Date  Sec HomeRate AwayRate  W/L RateDiff  Prediction  \
# ID
# 15010846 2015-03-07    1     1531     1404    0      127           1
# 15010922 2015-03-07    1     1512     1510    0        2           1
# 15011028 2015-03-07    1     1550     1472    1       78           1
# 15013378 2015-03-07    1     1533     1495    1       38           1
# 15015429 2015-03-07    1     1482     1404    1       78           1
# ...             ...  ...      ...      ...  ...      ...         ...
# 20340120 2020-12-19   34     1595     1559    0       36           1
# 20340810 2020-12-19   34     1514     1526    1      -12           2
# 20343331 2020-12-19   34     1455     1480    0      -25           2
# 20342218 2020-12-19   34     1541     1454    1       87           1
# 20340314 2020-12-19   34     1486     1466    2       20           1
#
#           Prediction2  WinProba  DrawProba  LossProba
# ID
# 15010846            1  0.515731      0.236   0.248269
# 15010922            0  0.384199      0.236   0.379801
# 15011028            1  0.466347      0.236   0.297653
# 15013378            1  0.423615      0.236   0.340385
# 15015429            1  0.466347      0.236   0.297653
# ...               ...       ...        ...        ...
# 20340120            1  0.421440      0.236   0.342560
# 20340810            0  0.368811      0.236   0.395189
# 20343331            2  0.354560      0.236   0.409440
# 20342218            1  0.475705      0.236   0.288295
# 20340314            0  0.403965      0.236   0.360035
#
# [1836 rows x 11 columns]

# %%
log_loss(df_rate_1520_pred["W/L"],df_rate_1520_pred[["DrawProba","WinProba","LossProba"]],labels=[0,1,2])
# Out:
# 1.0398917113267738
