# %%
import pandas as pd
import datetime
import csv

# %%
df= pd.read_csv("match_data/shim/shim_2020.csv")

# %%
df
# Out:
#     Unnamed: 0   節         開催日   曜日    相手  スコア  得点  失点 H/A    会場  ...  \
# 0            0   1  2020-02-23  (日)  FC東京  1-3   1   3   H  アイスタ  ...
# 1            1   2  2020-07-04  (土)   名古屋  1-2   1   2   H  アイスタ  ...
# 2            2   3  2020-07-08  (水)   Ｃ大阪  0-2   0   2   A  ヤンマー  ...
# 3            3   4  2020-07-12  (日)   Ｇ大阪  1-2   1   2   H  アイスタ  ...
# 4            4   5  2020-07-18  (土)    神戸  1-3   1   3   A  ノエスタ  ...
# 5            5   6  2020-07-22  (水)    鳥栖  1-1   1   1   A   駅スタ  ...
# 6            6   7  2020-07-26  (日)    大分  4-2   4   2   H  アイスタ  ...
# 7            7   8  2020-08-01  (土)    浦和  1-1   1   1   A    埼玉  ...
# 8            8   9  2020-08-08  (土)    札幌  3-1   3   1   H  アイスタ  ...
# 9            9  10  2020-08-15  (土)    仙台  0-0   0   0   A  ユアスタ  ...
# 10          10  11  2020-08-19  (水)  横浜FM  3-4   3   4   H  アイスタ  ...
# 11          11  12  2020-08-22  (土)  横浜FC  2-3   2   3   H  アイスタ  ...
# ...

# %%
 df = df.rename(columns={df.columns[2]: '曜日'})

# %%
df = df.rename(columns={df.columns[5]: 'H/A'})

# %%
df
# Out:
#     Unnamed: 0   節          曜日   曜日    相手  H/A  得点  失点 H/A    会場  ...  \
# 0            0   1  2020-02-23  (日)  FC東京  1-3   1   3   H  アイスタ  ...
# 1            1   2  2020-07-04  (土)   名古屋  1-2   1   2   H  アイスタ  ...
# 2            2   3  2020-07-08  (水)   Ｃ大阪  0-2   0   2   A  ヤンマー  ...
# 3            3   4  2020-07-12  (日)   Ｇ大阪  1-2   1   2   H  アイスタ  ...
# 4            4   5  2020-07-18  (土)    神戸  1-3   1   3   A  ノエスタ  ...
# 5            5   6  2020-07-22  (水)    鳥栖  1-1   1   1   A   駅スタ  ...
# 6            6   7  2020-07-26  (日)    大分  4-2   4   2   H  アイスタ  ...
# 7            7   8  2020-08-01  (土)    浦和  1-1   1   1   A    埼玉  ...
# 8            8   9  2020-08-08  (土)    札幌  3-1   3   1   H  アイスタ  ...
# 9            9  10  2020-08-15  (土)    仙台  0-0   0   0   A  ユアスタ  ...
# 10          10  11  2020-08-19  (水)  横浜FM  3-4   3   4   H  アイスタ  ...
# 11          11  12  2020-08-22  (土)  横浜FC  2-3   2   3   H  アイスタ  ...
# ...

# %%
df
# Out:
#     Unnamed: 0   節          曜日   曜日    相手  H/A  得点  失点 H/A    会場  ...  \
# 0            0   1  2020-02-23  (日)  FC東京  1-3   1   3   H  アイスタ  ...
# 1            1   2  2020-07-04  (土)   名古屋  1-2   1   2   H  アイスタ  ...
# 2            2   3  2020-07-08  (水)   Ｃ大阪  0-2   0   2   A  ヤンマー  ...
# 3            3   4  2020-07-12  (日)   Ｇ大阪  1-2   1   2   H  アイスタ  ...
# 4            4   5  2020-07-18  (土)    神戸  1-3   1   3   A  ノエスタ  ...
# 5            5   6  2020-07-22  (水)    鳥栖  1-1   1   1   A   駅スタ  ...
# 6            6   7  2020-07-26  (日)    大分  4-2   4   2   H  アイスタ  ...
# 7            7   8  2020-08-01  (土)    浦和  1-1   1   1   A    埼玉  ...
# 8            8   9  2020-08-08  (土)    札幌  3-1   3   1   H  アイスタ  ...
# 9            9  10  2020-08-15  (土)    仙台  0-0   0   0   A  ユアスタ  ...
# 10          10  11  2020-08-19  (水)  横浜FM  3-4   3   4   H  アイスタ  ...
# 11          11  12  2020-08-22  (土)  横浜FC  2-3   2   3   H  アイスタ  ...
# ...

# %%
df['観客数'] = df['観客数'].str.replace(',','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-14c2ea2853dd> in <module>
# ----> 1 df['観客数'] = df['観客数'].str.replace(',','').astype(int)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df['チャンス構築率'] = df['チャンス構築率'].str.replace('%','').astype(float)*0.01
df["チャンス構築率"] = df["チャンス構築率"].round(3)

# %%
df['シュート成功率']= df['シュート成功率'].str.replace('%','').astype(float).round(3)*0.01
df["シュート成功率"] = df["シュート成功率"].round(3)

# %%
df['支配率']= df['支配率'].str.replace('%','').astype(float).round(3)*0.01
df["支配率"] = df["支配率"].round(3)

# %%
df

# %%
for i in range(len(df["開催日"])):

        dt = datetime.datetime.strptime(f'2020.{df["開催日"][i]}', '%Y.%m.%d')
        df["開催日"][i] = datetime.date(dt.year, dt.month, dt.day)

# %%
df["開催日"]

# %%
df

# %%
score_list = []
concede_list = []
for i in range(len(df)):
        score,concede=map(int,df["スコア"][i].split("-"))
        score_list.append(score)
        concede_list.append(concede)

# %%
df.insert(5, '得点', score_list)
df.insert(6, '失点', concede_list)

# %%
df.dtypes

# %%
df

# %%
# for i in range(len(df)):
#     if df["得点者"][i] =NaN

# %%
# for i, r in df.iterrows():
#     if pd.isnull(r["得点者"]): #pd.isna(r["age"])でも同じ
#         print(type(i))
df=df.fillna("")

# %%
for i in range(len(df)):
    scorer_list = df["得点者"][i].split(",")
    df["得点者"][i] = scorer_list

# %%
df

# %%
# with open('shim_2020.csv', 'w') as f:
#     writer = csv.writer(f)
#     writer.writerows(df)
df.to_csv('match_data/shim_2020.csv')

# %%
df= pd.read_csv("match_data/shim/shim_2020.csv")

# %%
df
# Out:
#     Unnamed: 0   節         開催日   曜日    相手  スコア  得点  失点 H/A    会場  ...  \
# 0            0   1  2020-02-23  (日)  FC東京  1-3   1   3   H  アイスタ  ...
# 1            1   2  2020-07-04  (土)   名古屋  1-2   1   2   H  アイスタ  ...
# 2            2   3  2020-07-08  (水)   Ｃ大阪  0-2   0   2   A  ヤンマー  ...
# 3            3   4  2020-07-12  (日)   Ｇ大阪  1-2   1   2   H  アイスタ  ...
# 4            4   5  2020-07-18  (土)    神戸  1-3   1   3   A  ノエスタ  ...
# 5            5   6  2020-07-22  (水)    鳥栖  1-1   1   1   A   駅スタ  ...
# 6            6   7  2020-07-26  (日)    大分  4-2   4   2   H  アイスタ  ...
# 7            7   8  2020-08-01  (土)    浦和  1-1   1   1   A    埼玉  ...
# 8            8   9  2020-08-08  (土)    札幌  3-1   3   1   H  アイスタ  ...
# 9            9  10  2020-08-15  (土)    仙台  0-0   0   0   A  ユアスタ  ...
# 10          10  11  2020-08-19  (水)  横浜FM  3-4   3   4   H  アイスタ  ...
# 11          11  12  2020-08-22  (土)  横浜FC  2-3   2   3   H  アイスタ  ...
# ...

# %%
df["H/A"].replace("H",0)
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    0
# 14    1
# 15    0
# 16    1
# 17    1
# 18    0
# 19    1
# 20    1
# 21    0
# 22    1
# 23    0
# 24    1
# 25    0
# 26    0
# 27    1
# 28    1
# 29    0
# 30    0
# 31    1
# 32    0
# 33    1
# Name: H/A, dtype: int64

# %%
# df["H/A"]=df["H/A"].replace("A",1)

# %%
df["H/A"]
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    0
# 14    1
# 15    0
# 16    1
# 17    1
# 18    0
# 19    1
# 20    1
# 21    0
# 22    1
# 23    0
# 24    1
# 25    0
# 26    0
# 27    1
# 28    1
# 29    0
# 30    0
# 31    1
# 32    0
# 33    1
# Name: H/A, dtype: int64

# %%
df= pd.read_csv("match_data/shim/shim_2019.csv")

# %%
df["H/A"]
# Out:
# 0     A
# 1     H
# 2     A
# 3     A
# 4     H
# 5     A
# 6     A
# 7     H
# 8     H
# 9     A
# 10    H
# 11    A
# 12    H
# 13    A
# 14    H
# 15    A
# 16    A
# 17    H
# 18    A
# 19    H
# 20    A
# 21    H
# 22    H
# 23    A
# 24    H
# 25    H
# 26    A
# 27    A
# 28    H
# 29    H
# 30    A
# 31    H
# 32    A
# 33    H
# Name: H/A, dtype: object

# %%
df["H/A"] = df["H/A"].replace("H",0)
df["H/A"] = df["H/A"].replace("A",1)
df["H/A"]
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     1
# 7     0
# 8     0
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    0
# 15    1
# 16    1
# 17    0
# 18    1
# 19    0
# 20    1
# 21    0
# 22    0
# 23    1
# 24    0
# 25    0
# 26    1
# 27    1
# 28    0
# 29    0
# 30    1
# 31    0
# 32    1
# 33    0
# Name: H/A, dtype: int64

# %%
df["H/A"]
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     1
# 7     0
# 8     0
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    0
# 15    1
# 16    1
# 17    0
# 18    1
# 19    0
# 20    1
# 21    0
# 22    0
# 23    1
# 24    0
# 25    0
# 26    1
# 27    1
# 28    0
# 29    0
# 30    1
# 31    0
# 32    1
# 33    0
# Name: H/A, dtype: int64

# %%
df= pd.read_csv("match_data/shim/shim_2020.csv")

# %%
df
# Out:
#     Unnamed: 0   節         開催日   曜日    相手  スコア  得点  失点  H/A    会場  ...  \
# 0            0   1  2020-02-23  (日)  FC東京  1-3   1   3    0  アイスタ  ...
# 1            1   2  2020-07-04  (土)   名古屋  1-2   1   2    0  アイスタ  ...
# 2            2   3  2020-07-08  (水)   Ｃ大阪  0-2   0   2    1  ヤンマー  ...
# 3            3   4  2020-07-12  (日)   Ｇ大阪  1-2   1   2    0  アイスタ  ...
# 4            4   5  2020-07-18  (土)    神戸  1-3   1   3    1  ノエスタ  ...
# 5            5   6  2020-07-22  (水)    鳥栖  1-1   1   1    1   駅スタ  ...
# 6            6   7  2020-07-26  (日)    大分  4-2   4   2    0  アイスタ  ...
# 7            7   8  2020-08-01  (土)    浦和  1-1   1   1    1    埼玉  ...
# 8            8   9  2020-08-08  (土)    札幌  3-1   3   1    0  アイスタ  ...
# 9            9  10  2020-08-15  (土)    仙台  0-0   0   0    1  ユアスタ  ...
# 10          10  11  2020-08-19  (水)  横浜FM  3-4   3   4    0  アイスタ  ...
# 11          11  12  2020-08-22  (土)  横浜FC  2-3   2   3    0  アイスタ  ...
# ...

# %%
win_or_loss = 0

    
    
for r, i in df.iteritems():
    if df["得点"] > df["失点"]:
        win_or_loss = 1
    elif  df["失点"] > df["得点"]:
        win_or_loss = 2
    
    print(win_or_loss)
    
# df.insert(7, '勝敗', win_or_loss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c0f8fb59648a> in <module>
#       4
#       5 for i in df.iteritems():
# ----> 6     if df["得点"] > df["失点"]:
#       7         win_or_loss = 1
#       8     elif  df["失点"] > df["得点"]:
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1441     def __nonzero__(self):
#    1442         raise ValueError(
# -> 1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1445         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
