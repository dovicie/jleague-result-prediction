# %%
import csv
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from sklearn.metrics import log_loss
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import RandomForestRegressor

np.set_printoptions(suppress=True)

# %%
df_match_allyears = pd.read_csv("./match_data_yearly/all_years.csv", index_col=0)
df_match_allyears["Date"] = pd.to_datetime(df_match_allyears["Date"])
df_match_allyears
# Out:
#           Year  Sec       Date                  Home                 Away  \
# ID
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6012807   2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 6012231   2006    1 2006-03-05              fc-tokyo         oita-trinita
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...        ...  ...        ...                   ...                  ...
# 21380720  2021   38 2021-12-04       shimizu-s-pulse         cerezo-osaka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21381131  2021   38 2021-12-04        kashiwa-reysol         oita-trinita
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
#
#           HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  Attendances
# ID
# ...

# %%
df_stats = pd.read_csv("./stats.csv", index_col=0)
df_stats
# Out:
#           HomeShots  HomeShotsOnTarget  HomeShotsFromPK  HomePasses  \
# 12011413        8.0                3.0              0.0       284.0
# 12015401       13.0                3.0              0.0       424.0
# 12010807        7.0                2.0              1.0       311.0
# 12010918       18.0                9.0              0.0       502.0
# 12013320       16.0                6.0              0.0       264.0
# ...             ...                ...              ...         ...
# 21380720       20.0                5.0              0.0       337.0
# 21383318       15.0                2.0              0.0       451.0
# 21381131       15.0                8.0              0.0       446.0
# 21382223        9.0                4.0              0.0       516.0
# 21383610        8.0                5.0              0.0       698.0
#
#           HomeCrosses  HomeDirectFK  HomeIndirectFK  HomeCK  HomeThrowin  \
# 12011413          6.0          14.0             2.0     4.0         23.0
# ...

# %%
df_rate = pd.read_csv("./rating/all_years.csv", index_col=0, parse_dates=True)
df_rate
# Out:
#             kashima-antlers  urawa-red-diamonds  yokohama-fa-marinos  \
# 2006-03-04             1500                1500                 1500
# 2006-03-05             1500                1500                 1500
# 2006-03-06             1508                1500                 1508
# 2006-03-07             1508                1500                 1508
# 2006-03-08             1508                1500                 1508
# ...                     ...                 ...                  ...
# 2021-12-01             1593                1523                 1588
# 2021-12-02             1593                1523                 1588
# 2021-12-03             1593                1523                 1588
# 2021-12-04             1593                1523                 1588
# 2021-12-05             1597                1524                 1591
#
#             kawasaki-frontale  sanfrecce-hiroshima  vegalta-sendai  \
# 2006-03-04               1500                 1500            1350
# ...

# %%
for index,row in df_match_allyears.iterrows():
    home_rate = df_rate.loc[row["Date"], row["Home"]]
    away_rate = df_rate.loc[row["Date"], row["Away"]]
    
    df_match_allyears.at[index,"HomeRate"] = home_rate
    df_match_allyears.at[index,"AwayRate"] = away_rate 
    
df_match_allyears
# Out:
#           Year  Sec       Date                  Home                 Away  \
# ID
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6012807   2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 6012231   2006    1 2006-03-05              fc-tokyo         oita-trinita
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...        ...  ...        ...                   ...                  ...
# 21380720  2021   38 2021-12-04       shimizu-s-pulse         cerezo-osaka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21381131  2021   38 2021-12-04        kashiwa-reysol         oita-trinita
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
#
# ...

# %%
df_ranks= pd.read_csv("./ranks/all_years.csv",  index_col=0, parse_dates=True)

for index,row in df_match_allyears.iterrows():
    home_rank = df_ranks.loc[row["Date"], row["Home"]]
    away_rank = df_ranks.loc[row["Date"], row["Away"]]
    
    df_match_allyears.at[index,"HomeRank"] = home_rank
    df_match_allyears.at[index,"AwayRank"] = away_rank
    
df_match_allyears
# Out:
#           Year  Sec       Date                  Home                 Away  \
# ID
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6012807   2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 6012231   2006    1 2006-03-05              fc-tokyo         oita-trinita
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...        ...  ...        ...                   ...                  ...
# 21380720  2021   38 2021-12-04       shimizu-s-pulse         cerezo-osaka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21381131  2021   38 2021-12-04        kashiwa-reysol         oita-trinita
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
#
# ...

# %%
df_points = pd.read_csv("./points/all_years.csv" ,index_col=0, parse_dates=True)

for index,row in df_match_allyears.iterrows():
    home_points = df_points.loc[row["Date"], row["Home"]]
    away_points = df_points.loc[row["Date"], row["Away"]]
    
    df_match_allyears.at[index,"HomePoints"] = home_points
    df_match_allyears.at[index,"AwayPoints"] = away_points
    
df_match_allyears
# Out:
#           Year  Sec       Date                  Home                 Away  \
# ID
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6012807   2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 6012231   2006    1 2006-03-05              fc-tokyo         oita-trinita
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...        ...  ...        ...                   ...                  ...
# 21380720  2021   38 2021-12-04       shimizu-s-pulse         cerezo-osaka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21381131  2021   38 2021-12-04        kashiwa-reysol         oita-trinita
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
#
# ...

# %%
df_gd = pd.read_csv("./goal_differences/all_years.csv",index_col=0, parse_dates=True)

for index,row in df_match_allyears.iterrows():
    home_gd = df_gd.loc[row["Date"], row["Home"]]
    away_gd = df_gd.loc[row["Date"], row["Away"]]
    
    df_match_allyears.at[index,"HomeGD"] = home_gd
    df_match_allyears.at[index,"AwayGD"] = away_gd
    
df_match_allyears
# Out:
#           Year  Sec       Date                  Home                 Away  \
# ID
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6012807   2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse
# 6012231   2006    1 2006-03-05              fc-tokyo         oita-trinita
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# ...        ...  ...        ...                   ...                  ...
# 21380720  2021   38 2021-12-04       shimizu-s-pulse         cerezo-osaka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21381131  2021   38 2021-12-04        kashiwa-reysol         oita-trinita
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
#
# ...

# %%
df_allyears = pd.concat([df_match_allyears,df_stats],axis=1)
df_allyears
# Out:
#           Year  Sec       Date                  Home                 Away  \
# 6010524   2006    1 2006-03-05   yokohama-fa-marinos          kyoto-sanga
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6011001   2006    1 2006-03-05   sanfrecce-hiroshima      kashima-antlers
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# ...        ...  ...        ...                   ...                  ...
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21383414  2021   38 2021-12-04           yokohama-fc    consadole-sapporo
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
# 21385401  2021   38 2021-12-04        vegalta-sendai      kashima-antlers
#
#           HomeID  AwayID  HomeGF  AwayGF  W/L  ... AwayClearances  \
# ...

# %%
df = df_allyears[df_allyears["Year"] >= 2012]
df
# Out:
#           Year  Sec       Date                  Home                 Away  \
# 12010807  2012    1 2012-03-10  nagoya-grampus-eight      shimizu-s-pulse
# 12010918  2012    1 2012-03-10           gamba-osaka          vissel-kobe
# 12011003  2012    1 2012-03-10   sanfrecce-hiroshima   urawa-red-diamonds
# 12011105  2012    1 2012-03-11        kashiwa-reysol  yokohama-fa-marinos
# 12011413  2012    1 2012-03-10     consadole-sapporo         jubilo-iwata
# ...        ...  ...        ...                   ...                  ...
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21383414  2021   38 2021-12-04           yokohama-fc    consadole-sapporo
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
# 21385401  2021   38 2021-12-04        vegalta-sendai      kashima-antlers
#
#           HomeID  AwayID  HomeGF  AwayGF  W/L  ... AwayClearances  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.get_dummies(df, columns=["Home","Away"])
df
# Out:
#           Year  Sec       Date  HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  \
# 12010807  2012    1 2012-03-10       8       7       1       0    1     豊田ス
# 12010918  2012    1 2012-03-10       9      18       2       3    2      万博
# 12011003  2012    1 2012-03-10      10       3       1       0    1     広島ビ
# 12011105  2012    1 2012-03-11      11       5       3       3    0       柏
# 12011413  2012    1 2012-03-10      14      13       0       0    0     札幌ド
# ...        ...  ...        ...     ...     ...     ...     ...  ...     ...
# 21382223  2021   38 2021-12-04      22      23       0       0    0     味スタ
# 21383318  2021   38 2021-12-04      33      18       0       2    2     駅スタ
# 21383414  2021   38 2021-12-04      34      14       0       1    2    ニッパツ
# 21383610  2021   38 2021-12-04      36      10       2       4    2    鳴門大塚
# 21385401  2021   38 2021-12-04      54       1       0       1    2    ユアスタ
#
# ...

# %%
print(list(df.columns))
# Out:
# ['Year', 'Sec', 'Date', 'HomeID', 'AwayID', 'HomeGF', 'AwayGF', 'W/L', 'Stadium', 'Attendances', 'HomeRate', 'AwayRate', 'HomeRank', 'AwayRank', 'HomePoints', 'AwayPoints', 'HomeGD', 'AwayGD', 'HomeShots', 'HomeShotsOnTarget', 'HomeShotsFromPK', 'HomePasses', 'HomeCrosses', 'HomeDirectFK', 'HomeIndirectFK', 'HomeCK', 'HomeThrowin', 'HomeDribbling', 'HomeTackles', 'HomeClearances', 'HomeIntercepts', 'HomeOffsides', 'HomeYellowCards', 'HomeRedCards', 'Home30mLineEntries', 'HomePenaltyAreaEntries', 'HomeAttacks', 'HomeChanceBuildingRate', 'HomePossession', 'AwayShots', 'AwayShotsOnTarget', 'AwayShotsFromPK', 'AwayPasses', 'AwayCrosses', 'AwayDirectFK', 'AwayIndirectFK', 'AwayCK', 'AwayThrowin', 'AwayDribbling', 'AwayTackles', 'AwayClearances', 'AwayIntercepts', 'AwayOffsides', 'AwayYellowCards', 'AwayRedCards', 'Away30mLineEntries', 'AwayPenaltyAreaEntries', 'AwayAttacks', 'AwayChanceBuildingRate', 'AwayPossession', 'Home_albirex-niigata', 'Home_avispa-fukuoka', 'Home_cerezo-osaka', 'Ho
# ...

# %% [markdown]
# ### statsを回帰

# %%
X1_features =  [
    'Year', 'Sec', 'Attendances', 'HomeRate', 'AwayRate', 'HomeRank', 'AwayRank', 'HomePoints', 'AwayPoints', 'HomeGD', 'AwayGD', 
    'Home_albirex-niigata', 'Home_avispa-fukuoka', 'Home_cerezo-osaka', 'Home_consadole-sapporo', 'Home_fc-tokyo', 'Home_gamba-osaka',
    'Home_jubilo-iwata', 'Home_kashima-antlers', 'Home_kashiwa-reysol', 'Home_kawasaki-frontale', 'Home_matsumoto-yamaga', 
    'Home_montedio-yamagata', 'Home_nagoya-grampus-eight', 'Home_oita-trinita', 'Home_omiya-ardija', 'Home_sagan-tosu', 
    'Home_sanfrecce-hiroshima', 'Home_shimizu-s-pulse', 'Home_shonan-bellmare', 'Home_tokushima-vortis', 'Home_urawa-red-diamonds',
    'Home_v-varen-nagasaki', 'Home_vegalta-sendai', 'Home_ventforet-kofu', 'Home_vissel-kobe', 'Home_yokohama-fa-marinos',
    'Home_yokohama-fc', 'Away_albirex-niigata', 'Away_avispa-fukuoka', 'Away_cerezo-osaka', 'Away_consadole-sapporo', 'Away_fc-tokyo', 
    'Away_gamba-osaka', 'Away_jubilo-iwata', 'Away_kashima-antlers', 'Away_kashiwa-reysol', 'Away_kawasaki-frontale',
    'Away_matsumoto-yamaga', 'Away_montedio-yamagata', 'Away_nagoya-grampus-eight', 'Away_oita-trinita', 'Away_omiya-ardija',
    'Away_sagan-tosu', 'Away_sanfrecce-hiroshima', 'Away_shimizu-s-pulse', 'Away_shonan-bellmare', 'Away_tokushima-vortis', 
    'Away_urawa-red-diamonds', 'Away_v-varen-nagasaki', 'Away_vegalta-sendai', 'Away_ventforet-kofu', 'Away_vissel-kobe',
    'Away_yokohama-fa-marinos', 'Away_yokohama-fc'
]

# %%
Y1_features = [
    'HomeShots', 'HomeShotsOnTarget', 'HomeShotsFromPK', 'HomePasses', 'HomeCrosses', 'HomeDirectFK', 'HomeIndirectFK',
    'HomeCK', 'HomeThrowin', 'HomeDribbling', 'HomeTackles', 'HomeClearances', 'HomeIntercepts', 'HomeOffsides', 'HomeYellowCards',
    'HomeRedCards', 'Home30mLineEntries', 'HomePenaltyAreaEntries', 'HomeAttacks', 'HomeChanceBuildingRate', 'HomePossession',
    'AwayShots', 'AwayShotsOnTarget', 'AwayShotsFromPK', 'AwayPasses', 'AwayCrosses', 'AwayDirectFK', 'AwayIndirectFK', 'AwayCK',
    'AwayThrowin', 'AwayDribbling', 'AwayTackles', 'AwayClearances', 'AwayIntercepts', 'AwayOffsides', 'AwayYellowCards', 'AwayRedCards',
    'Away30mLineEntries', 'AwayPenaltyAreaEntries', 'AwayAttacks', 'AwayChanceBuildingRate', 'AwayPossession'
]

# %%
df_stats_pred = pd.DataFrame( columns=Y1_features)
for year in range(2014,2021):

    X1_train = df[(df["Year"] == (year-2)) | (df["Year"] == (year-1))].dropna(how="any")[X1_features].values
    Y1_train = df[(df["Year"] == (year-2)) | (df["Year"] == (year-1))].dropna(how="any")[Y1_features].values

    X1_test = df[df["Year"] == year][X1_features].values
    Y1_test = df[df["Year"] == year][Y1_features].values
    
    reg = RandomForestRegressor(random_state=1234)
    reg.fit(X1_train,Y1_train)
    
    Y1_pred=reg.predict(X1_test)
    df_Y1_pred = pd.DataFrame(Y1_pred, index=df[df["Year"]==year].index, columns=Y1_features)
    df_stats_pred = pd.concat([df_stats_pred, df_Y1_pred])

# %%
df_stats_pred
# Out:
#           HomeShots  HomeShotsOnTarget  HomeShotsFromPK  HomePasses  \
# 14010527      15.34               4.88             0.19      490.88
# 14010807      13.48               4.26             0.23      432.70
# 14010903      11.85               4.18             0.03      355.02
# 14011122      14.20               5.31             0.06      455.36
# 14012010      14.19               5.07             0.07      463.51
# ...             ...                ...              ...         ...
# 20341121       9.94               3.17             0.03      459.88
# 20342218      15.18               4.85             0.14      537.91
# 20343331      13.89               4.35             0.03      351.15
# 20343405      10.86               3.16             0.07      317.11
# 20345412      16.54               5.27             0.12      421.59
#
#           HomeCrosses  HomeDirectFK  HomeIndirectFK  HomeCK  HomeThrowin  \
# 14010527        16.20         14.24            2.29    5.59        23.64
# ...

# %% [markdown]
# ### statsを使って勝敗予測

# %%
df2 = pd.concat([df_match_allyears,df_stats_pred],axis=1)
df2
# Out:
#           Year  Sec       Date                  Home                 Away  \
# 6010524   2006    1 2006-03-05   yokohama-fa-marinos          kyoto-sanga
# 6010820   2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka
# 6010903   2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds
# 6011001   2006    1 2006-03-05   sanfrecce-hiroshima      kashima-antlers
# 6011323   2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka
# ...        ...  ...        ...                   ...                  ...
# 21382223  2021   38 2021-12-04              fc-tokyo       avispa-fukuoka
# 21383318  2021   38 2021-12-04            sagan-tosu          vissel-kobe
# 21383414  2021   38 2021-12-04           yokohama-fc    consadole-sapporo
# 21383610  2021   38 2021-12-04      tokushima-vortis  sanfrecce-hiroshima
# 21385401  2021   38 2021-12-04        vegalta-sendai      kashima-antlers
#
#           HomeID  AwayID  HomeGF  AwayGF  W/L  ... AwayClearances  \
# ...

# %%
X2_features = [ 
    'Sec', 'HomeRate', 'AwayRate','HomeRank', 'AwayRank', 'HomePoints', 'AwayPoints', 'HomeGD', 'AwayGD','HomeShots', 'HomeShotsOnTarget', 'HomeShotsFromPK', 'HomePasses',
    'HomeCrosses', 'HomeDirectFK', 'HomeIndirectFK', 'HomeCK','HomeThrowin', 'HomeDribbling', 'HomeTackles', 'HomeClearances',
    'HomeIntercepts', 'HomeOffsides', 'HomeYellowCards', 'HomeRedCards','Home30mLineEntries', 'HomePenaltyAreaEntries', 'HomeAttacks',
    'HomeChanceBuildingRate', 'HomePossession', 'AwayShots','AwayShotsOnTarget', 'AwayShotsFromPK', 'AwayPasses', 'AwayCrosses',
    'AwayDirectFK', 'AwayIndirectFK', 'AwayCK', 'AwayThrowin','AwayDribbling', 'AwayTackles', 'AwayClearances', 'AwayIntercepts',
    'AwayOffsides', 'AwayYellowCards', 'AwayRedCards', 'Away30mLineEntries','AwayPenaltyAreaEntries', 
    'AwayAttacks', 'AwayChanceBuildingRate','AwayPossession'
]


accuracies = []
loglosses = []

feature_imps = []

for  year in range(2015, 2021):
    
    print(f"=={year}=================================")
    
    X2_train = df2[(df2["Year"] == (year-3)) | (df2["Year"] == (year-2)) | (df2["Year"] == (year-1))].dropna(how="any")[X2_features].values
    y2_train = df2[(df2["Year"] == (year-3)) | (df2["Year"] == (year-2)) | (df2["Year"] == (year-1))].dropna(how="any")["W/L"].values
    
    X2_test = df2[df2["Year"] == year][X2_features].values
    y2_test = df2[df2["Year"] == year]["W/L"].values
    
    clf = RandomForestClassifier(random_state=1234,max_depth=7)
    clf.fit(X2_train, y2_train)
    
    y2_pred_proba = clf.predict_proba(X2_test)
    
    accuracy = clf.score(X2_test, y2_test)
    accuracies.append(accuracy)
    
    feature_imps.append( clf.feature_importances_.tolist())
    
    logloss = log_loss(y2_test,y2_pred_proba,labels=[0,1,2])
    loglosses.append(logloss)
    
    print(f"Accuracy : {accuracy}")
    print(f"Log loss : {logloss}")
    print(" ")
    
print(" ")
print("======================================")    
print(f"的中率(Accuracy) : {np.mean(accuracies)}" )
print(f"対数損失(Log loss) : {np.mean(loglosses)}" )
# Out:
# ==2015=================================
# Accuracy : 0.4117647058823529
# Log loss : 1.0738738626051116
#
# ==2016=================================
# Accuracy : 0.5032679738562091
# Log loss : 1.0327279815755517
#
# ==2017=================================
# Accuracy : 0.48366013071895425
# Log loss : 1.0568695706706306
#
# ==2018=================================
# Accuracy : 0.4215686274509804
# Log loss : 1.0815570180544412
#
# ==2019=================================
# Accuracy : 0.4117647058823529
# Log loss : 1.082536649952025
#
# ==2020=================================
# Accuracy : 0.46405228758169936
# Log loss : 1.042943532936705
#
#
# ...
# 的中率(Accuracy) : 0.4493464052287582
# 対数損失(Log loss) : 1.0617514359657443

# %%
pd.DataFrame(np.mean(np.array(feature_imps),axis=0), index = X2_features).sort_values(0,ascending = False).head(20)
# Out:
#                                0
# AwayPossession          0.028818
# HomePasses              0.027324
# HomePossession          0.024845
# HomeYellowCards         0.024827
# Home30mLineEntries      0.024663
# AwayShotsOnTarget       0.024119
# AwayPenaltyAreaEntries  0.022963
# HomeRate                0.022250
# HomePenaltyAreaEntries  0.022159
# HomeDirectFK            0.022038
# HomeChanceBuildingRate  0.021793
# AwayOffsides            0.021789
# AwayYellowCards         0.021705
# HomeDribbling           0.021572
# AwayRate                0.021391
# HomeShots               0.021156
# HomeOffsides            0.021067
# AwayCK                  0.020816
# AwayIntercepts          0.020813
# AwayChanceBuildingRate  0.020692

# %% [markdown]
# statsの回帰がうまくいってないのか､全然的中させられない｡
