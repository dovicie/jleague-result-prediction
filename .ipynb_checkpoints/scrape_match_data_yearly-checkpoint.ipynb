# %%
import re
import csv
import time
import requests
import datetime
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://data.j-league.or.jp/SFMS01/search?competition_years=2010&competition_frame_ids=1' 
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
records = soup.find_all('tr')
data = []
for record in records[:-9]:
    l = [field.text for field in record.find_all(['th','td'])]           
    data.append(l)

with open('./match_data_yearly/2010.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
df = pd.read_csv(f'./match_data_yearly/2010.csv')
club_and_id = pd.read_csv('./club_and_id.csv')

# %%
df
# Out:
#        年度   大会        節       試合日                                  K/O時刻  \
# 0    2010  Ｊ１    第１節第１日  03/06(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t13:03
# 1    2010  Ｊ１    第１節第１日  03/06(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t13:04
# 2    2010  Ｊ１    第１節第１日  03/06(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t14:01
# 3    2010  Ｊ１    第１節第１日  03/06(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t14:04
# 4    2010  Ｊ１    第１節第１日  03/06(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t16:03
# ..    ...  ...      ...       ...                                    ...
# 301  2010  Ｊ１   第３４節第１日  12/04(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15:34
# 302  2010  Ｊ１   第３４節第１日  12/04(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15:34
# 303  2010  Ｊ１   第３４節第１日  12/04(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15:34
# 304  2010  Ｊ１   第３４節第１日  12/04(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15:34
# 305  2010  Ｊ１   第３４節第１日  12/04(土)  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15:37
#
#          ホーム      スコア      アウェイ                                 スタジアム  \
# 0     \n磐田\n  \n0-1\n    \n仙台\n   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tヤマハ
# 1     \n湘南\n  \n1-1\n    \n山形\n    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t平塚
# 2    \nＦ東京\n  \n1-0\n  \n横浜FM\n   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t味スタ
# 3     \n広島\n  \n1-1\n    \n清水\n   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t広島ビ
# 4    \n川崎Ｆ\n  \n2-1\n    \n新潟\n   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t等々力
# ..       ...      ...       ...                                   ...
# 301   \n山形\n  \n1-1\n    \n鹿島\n  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tＮＤスタ
# 302   \n浦和\n  \n0-4\n    \n神戸\n    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t埼玉
# 303   \n新潟\n  \n3-1\n    \n湘南\n  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t東北電ス
# 304  \n名古屋\n  \n2-1\n    \n広島\n   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t豊田ス
# 305  \nＣ大阪\n  \n6-2\n    \n磐田\n  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t金鳥スタ
#
#                                        入場者数  \
# 0    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t10,440
# 1    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t11,280
# 2    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t29,011
# 3    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t16,216
# 4    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t22,117
# ..                                      ...
# 301  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t13,647
# 302  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t45,941
# 303  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t27,389
# 304  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t31,941
# 305  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15,011
#
#                            インターネット中継・TV放送
# 0      スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャンＨＤ／静岡放送
# 1             スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャン
# 2    スカパー・ｅ２（ＴＢＳチャンネル）／ＴＢＳ（単）／ＴＯＫＹＯ　ＭＸ（録）
# 3      スカパー・ｅ２（Ｊ　ｓｐｏｒｔｓ　Ｐｌｕｓ）／ＮＨＫ広島／ＮＨＫ静岡
# 4           スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャンＨＤ
# ..                                    ...
# 301           スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャン
# 302  スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャンＨＤ／ＢＳ／テレ玉
# 303     スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャン／ＮＨＫ新潟
# 304           スカパー（スカチャンＨＤ、スカチャン）／ｅ２スカチャン
# 305              スカパー・ｅ２（ＴＢＳチャンネル）／ＢＳ－ＴＢＳ
#
# [306 rows x 11 columns]

# %%
club_and_id
# Out:
#     club_id                  club club_ja
# 0         1       kashima-antlers      鹿島
# 1         2            jef-united      千葉
# 2         3    urawa-red-diamonds      浦和
# 3         4           tokyo-verdy     東京Ｖ
# 4         5   yokohama-fa-marinos    横浜FM
# 5         6      yokohama-flugels     横浜Ｆ
# 6         7       shimizu-s-pulse      清水
# 7         8  nagoya-grampus-eight     名古屋
# 8         9           gamba-osaka     Ｇ大阪
# 9        10   sanfrecce-hiroshima      広島
# 10       11        kashiwa-reysol       柏
# 11       12       shonan-bellmare      湘南
# 12       13          jubilo-iwata      磐田
# 13       14     consadole-sapporo      札幌
# 14       18           vissel-kobe      神戸
# 15       20          cerezo-osaka     Ｃ大阪
# 16       21     kawasaki-frontale     川崎Ｆ
# 17       22              fc-tokyo    FC東京
# 18       23        avispa-fukuoka      福岡
# 19       24           kyoto-sanga      京都
# 20       27          omiya-ardija      大宮
# 21       28        ventforet-kofu      甲府
# 22       29     montedio-yamagata      山形
# 23       31          oita-trinita      大分
# 24       33            sagan-tosu      鳥栖
# 25       34           yokohama-fc    横浜FC
# 26       36      tokushima-vortis      徳島
# 27       46      matsumoto-yamaga      松本
# 28       47      v-varen-nagasaki      長崎
# 29       54        vegalta-sendai      仙台
# 30       78       albirex-niigata      新潟
# 31       22              fc-tokyo     Ｆ東京

# %%
df = df.drop({"K/O時刻" ,"大会","インターネット中継・TV放送"}, axis=1) 
df = df.rename(columns={'年度':'Year','節': 'Sec', '試合日': 'Date',  'ホーム': 'Home','スコア':'Score', 'アウェイ': 'Away','スタジアム': 'Stadium', '入場者数': 'Attendances'})

# %%
df
# Out:
#      Year      Sec      Date     Home    Score      Away  \
# 0    2010   第１節第１日  03/06(土)   \n磐田\n  \n0-1\n    \n仙台\n
# 1    2010   第１節第１日  03/06(土)   \n湘南\n  \n1-1\n    \n山形\n
# 2    2010   第１節第１日  03/06(土)  \nＦ東京\n  \n1-0\n  \n横浜FM\n
# 3    2010   第１節第１日  03/06(土)   \n広島\n  \n1-1\n    \n清水\n
# 4    2010   第１節第１日  03/06(土)  \n川崎Ｆ\n  \n2-1\n    \n新潟\n
# ..    ...      ...       ...      ...      ...       ...
# 301  2010  第３４節第１日  12/04(土)   \n山形\n  \n1-1\n    \n鹿島\n
# 302  2010  第３４節第１日  12/04(土)   \n浦和\n  \n0-4\n    \n神戸\n
# 303  2010  第３４節第１日  12/04(土)   \n新潟\n  \n3-1\n    \n湘南\n
# 304  2010  第３４節第１日  12/04(土)  \n名古屋\n  \n2-1\n    \n広島\n
# 305  2010  第３４節第１日  12/04(土)  \nＣ大阪\n  \n6-2\n    \n磐田\n
#
#                                   Stadium  \
# 0     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tヤマハ
# 1      \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t平塚
# 2     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t味スタ
# 3     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t広島ビ
# 4     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t等々力
# ..                                    ...
# 301  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tＮＤスタ
# 302    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t埼玉
# 303  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t東北電ス
# 304   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t豊田ス
# 305  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t金鳥スタ
#
#                                 Attendances
# 0    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t10,440
# 1    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t11,280
# 2    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t29,011
# 3    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t16,216
# 4    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t22,117
# ..                                      ...
# 301  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t13,647
# 302  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t45,941
# 303  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t27,389
# 304  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t31,941
# 305  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t15,011
#
# [306 rows x 8 columns]

# %%
df = df.replace({'\t','\r','\n'},'',regex=True)
df
# Out:
#      Year      Sec      Date Home Score  Away Stadium Attendances
# 0    2010   第１節第１日  03/06(土)   磐田   0-1    仙台     ヤマハ      10,440
# 1    2010   第１節第１日  03/06(土)   湘南   1-1    山形      平塚      11,280
# 2    2010   第１節第１日  03/06(土)  Ｆ東京   1-0  横浜FM     味スタ      29,011
# 3    2010   第１節第１日  03/06(土)   広島   1-1    清水     広島ビ      16,216
# 4    2010   第１節第１日  03/06(土)  川崎Ｆ   2-1    新潟     等々力      22,117
# ..    ...      ...       ...  ...   ...   ...     ...         ...
# 301  2010  第３４節第１日  12/04(土)   山形   1-1    鹿島    ＮＤスタ      13,647
# 302  2010  第３４節第１日  12/04(土)   浦和   0-4    神戸      埼玉      45,941
# 303  2010  第３４節第１日  12/04(土)   新潟   3-1    湘南    東北電ス      27,389
# 304  2010  第３４節第１日  12/04(土)  名古屋   2-1    広島     豊田ス      31,941
# 305  2010  第３４節第１日  12/04(土)  Ｃ大阪   6-2    磐田    金鳥スタ      15,011
#
# [306 rows x 8 columns]

# %%
df ["Date"] = df["Date"].replace('\(.+\)','',regex=True)
for index,row in df.iterrows():
    df.at[index,"Date"] = datetime.datetime.strptime(f'{row["Year"]}/{row["Date"]}','%Y/%m/%d')

# %%
df
# Out:
#      Year      Sec                 Date Home Score  Away Stadium Attendances
# 0    2010   第１節第１日  2010-03-06 00:00:00   磐田   0-1    仙台     ヤマハ      10,440
# 1    2010   第１節第１日  2010-03-06 00:00:00   湘南   1-1    山形      平塚      11,280
# 2    2010   第１節第１日  2010-03-06 00:00:00  Ｆ東京   1-0  横浜FM     味スタ      29,011
# 3    2010   第１節第１日  2010-03-06 00:00:00   広島   1-1    清水     広島ビ      16,216
# 4    2010   第１節第１日  2010-03-06 00:00:00  川崎Ｆ   2-1    新潟     等々力      22,117
# ..    ...      ...                  ...  ...   ...   ...     ...         ...
# 301  2010  第３４節第１日  2010-12-04 00:00:00   山形   1-1    鹿島    ＮＤスタ      13,647
# 302  2010  第３４節第１日  2010-12-04 00:00:00   浦和   0-4    神戸      埼玉      45,941
# 303  2010  第３４節第１日  2010-12-04 00:00:00   新潟   3-1    湘南    東北電ス      27,389
# 304  2010  第３４節第１日  2010-12-04 00:00:00  名古屋   2-1    広島     豊田ス      31,941
# 305  2010  第３４節第１日  2010-12-04 00:00:00  Ｃ大阪   6-2    磐田    金鳥スタ      15,011
#
# [306 rows x 8 columns]

# %%
df["Sec"] =df["Sec"].replace({'第','節.+日'},'',regex=True).astype(int)
df
# Out:
#      Year  Sec                 Date Home Score  Away Stadium Attendances
# 0    2010    1  2010-03-06 00:00:00   磐田   0-1    仙台     ヤマハ      10,440
# 1    2010    1  2010-03-06 00:00:00   湘南   1-1    山形      平塚      11,280
# 2    2010    1  2010-03-06 00:00:00  Ｆ東京   1-0  横浜FM     味スタ      29,011
# 3    2010    1  2010-03-06 00:00:00   広島   1-1    清水     広島ビ      16,216
# 4    2010    1  2010-03-06 00:00:00  川崎Ｆ   2-1    新潟     等々力      22,117
# ..    ...  ...                  ...  ...   ...   ...     ...         ...
# 301  2010   34  2010-12-04 00:00:00   山形   1-1    鹿島    ＮＤスタ      13,647
# 302  2010   34  2010-12-04 00:00:00   浦和   0-4    神戸      埼玉      45,941
# 303  2010   34  2010-12-04 00:00:00   新潟   3-1    湘南    東北電ス      27,389
# 304  2010   34  2010-12-04 00:00:00  名古屋   2-1    広島     豊田ス      31,941
# 305  2010   34  2010-12-04 00:00:00  Ｃ大阪   6-2    磐田    金鳥スタ      15,011
#
# [306 rows x 8 columns]

# %%
df.insert(6, 'HomeID',np.nan)
df.insert(7, 'AwayID', np.nan)
df
# Out:
#      Year  Sec                 Date Home Score  Away  HomeID  AwayID Stadium  \
# 0    2010    1  2010-03-06 00:00:00   磐田   0-1    仙台     NaN     NaN     ヤマハ
# 1    2010    1  2010-03-06 00:00:00   湘南   1-1    山形     NaN     NaN      平塚
# 2    2010    1  2010-03-06 00:00:00  Ｆ東京   1-0  横浜FM     NaN     NaN     味スタ
# 3    2010    1  2010-03-06 00:00:00   広島   1-1    清水     NaN     NaN     広島ビ
# 4    2010    1  2010-03-06 00:00:00  川崎Ｆ   2-1    新潟     NaN     NaN     等々力
# ..    ...  ...                  ...  ...   ...   ...     ...     ...     ...
# 301  2010   34  2010-12-04 00:00:00   山形   1-1    鹿島     NaN     NaN    ＮＤスタ
# 302  2010   34  2010-12-04 00:00:00   浦和   0-4    神戸     NaN     NaN      埼玉
# 303  2010   34  2010-12-04 00:00:00   新潟   3-1    湘南     NaN     NaN    東北電ス
# 304  2010   34  2010-12-04 00:00:00  名古屋   2-1    広島     NaN     NaN     豊田ス
# 305  2010   34  2010-12-04 00:00:00  Ｃ大阪   6-2    磐田     NaN     NaN    金鳥スタ
#
#     Attendances
# 0        10,440
# 1        11,280
# 2        29,011
# 3        16,216
# 4        22,117
# ..          ...
# 301      13,647
# 302      45,941
# 303      27,389
# 304      31,941
# 305      15,011
#
# [306 rows x 10 columns]

# %%
for index,row in df.iterrows():
    for i,r in club_and_id.iterrows():
        if row["Home"] == r["club_ja"]:
            df.at[index, "HomeID"] = r["club_id"]
            df.at[index,"Home"] = r["club"]


    for i,r in club_and_id.iterrows():
        if row["Away"] == r["club_ja"]:
            df.at[index,"AwayID"] = r["club_id"]
            df.at[index,"Away"] = r["club"]

df[['HomeID', 'AwayID']] = df[['HomeID', 'AwayID']].astype('int')
df
# Out:
#      Year  Sec                 Date                  Home Score  \
# 0    2010    1  2010-03-06 00:00:00          jubilo-iwata   0-1
# 1    2010    1  2010-03-06 00:00:00       shonan-bellmare   1-1
# 2    2010    1  2010-03-06 00:00:00              fc-tokyo   1-0
# 3    2010    1  2010-03-06 00:00:00   sanfrecce-hiroshima   1-1
# 4    2010    1  2010-03-06 00:00:00     kawasaki-frontale   2-1
# ..    ...  ...                  ...                   ...   ...
# 301  2010   34  2010-12-04 00:00:00     montedio-yamagata   1-1
# 302  2010   34  2010-12-04 00:00:00    urawa-red-diamonds   0-4
# 303  2010   34  2010-12-04 00:00:00       albirex-niigata   3-1
# 304  2010   34  2010-12-04 00:00:00  nagoya-grampus-eight   2-1
# 305  2010   34  2010-12-04 00:00:00          cerezo-osaka   6-2
#
#                     Away  HomeID  AwayID Stadium Attendances
# 0         vegalta-sendai      13      54     ヤマハ      10,440
# 1      montedio-yamagata      12      29      平塚      11,280
# 2    yokohama-fa-marinos      22       5     味スタ      29,011
# 3        shimizu-s-pulse      10       7     広島ビ      16,216
# 4        albirex-niigata      21      78     等々力      22,117
# ..                   ...     ...     ...     ...         ...
# 301      kashima-antlers      29       1    ＮＤスタ      13,647
# 302          vissel-kobe       3      18      埼玉      45,941
# 303      shonan-bellmare      78      12    東北電ス      27,389
# 304  sanfrecce-hiroshima       8      10     豊田ス      31,941
# 305         jubilo-iwata      20      13    金鳥スタ      15,011
#
# [306 rows x 10 columns]

# %%
df.insert(8, 'HomeGF', np.nan)
df.insert(9, 'AwayGF', np.nan)

for index,row in df.iterrows():
    home_gf,away_gf = map(int,row["Score"].split("-"))
    df.at[index,"HomeGF"] = home_gf
    df.at[index,"AwayGF"] = away_gf
df[['HomeGF', 'AwayGF']] = df[['HomeGF', 'AwayGF']].astype('int')
df
# Out:
#      Year  Sec                 Date                  Home Score  \
# 0    2010    1  2010-03-06 00:00:00          jubilo-iwata   0-1
# 1    2010    1  2010-03-06 00:00:00       shonan-bellmare   1-1
# 2    2010    1  2010-03-06 00:00:00              fc-tokyo   1-0
# 3    2010    1  2010-03-06 00:00:00   sanfrecce-hiroshima   1-1
# 4    2010    1  2010-03-06 00:00:00     kawasaki-frontale   2-1
# ..    ...  ...                  ...                   ...   ...
# 301  2010   34  2010-12-04 00:00:00     montedio-yamagata   1-1
# 302  2010   34  2010-12-04 00:00:00    urawa-red-diamonds   0-4
# 303  2010   34  2010-12-04 00:00:00       albirex-niigata   3-1
# 304  2010   34  2010-12-04 00:00:00  nagoya-grampus-eight   2-1
# 305  2010   34  2010-12-04 00:00:00          cerezo-osaka   6-2
#
#                     Away  HomeID  AwayID  HomeGF  AwayGF Stadium Attendances
# 0         vegalta-sendai      13      54       0       1     ヤマハ      10,440
# 1      montedio-yamagata      12      29       1       1      平塚      11,280
# 2    yokohama-fa-marinos      22       5       1       0     味スタ      29,011
# 3        shimizu-s-pulse      10       7       1       1     広島ビ      16,216
# 4        albirex-niigata      21      78       2       1     等々力      22,117
# ..                   ...     ...     ...     ...     ...     ...         ...
# 301      kashima-antlers      29       1       1       1    ＮＤスタ      13,647
# 302          vissel-kobe       3      18       0       4      埼玉      45,941
# 303      shonan-bellmare      78      12       3       1    東北電ス      27,389
# 304  sanfrecce-hiroshima       8      10       2       1     豊田ス      31,941
# 305         jubilo-iwata      20      13       6       2    金鳥スタ      15,011
#
# [306 rows x 12 columns]

# %%
df.insert(10,'W/L',np.nan) 

for index,row in df.iterrows():
        if row["HomeGF"] >row["AwayGF"]:
            df.at[index,"W/L"] = 1
        elif row["HomeGF"] < row["AwayGF"]:
            df.at[index,"W/L"] = 2
        else:
            df.at[index,"W/L"] = 0
            
df['W/L'] = df['W/L'].astype('int')
df
# Out:
#      Year  Sec                 Date                  Home Score  \
# 0    2010    1  2010-03-06 00:00:00          jubilo-iwata   0-1
# 1    2010    1  2010-03-06 00:00:00       shonan-bellmare   1-1
# 2    2010    1  2010-03-06 00:00:00              fc-tokyo   1-0
# 3    2010    1  2010-03-06 00:00:00   sanfrecce-hiroshima   1-1
# 4    2010    1  2010-03-06 00:00:00     kawasaki-frontale   2-1
# ..    ...  ...                  ...                   ...   ...
# 301  2010   34  2010-12-04 00:00:00     montedio-yamagata   1-1
# 302  2010   34  2010-12-04 00:00:00    urawa-red-diamonds   0-4
# 303  2010   34  2010-12-04 00:00:00       albirex-niigata   3-1
# 304  2010   34  2010-12-04 00:00:00  nagoya-grampus-eight   2-1
# 305  2010   34  2010-12-04 00:00:00          cerezo-osaka   6-2
#
#                     Away  HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  \
# 0         vegalta-sendai      13      54       0       1    2     ヤマハ
# 1      montedio-yamagata      12      29       1       1    0      平塚
# 2    yokohama-fa-marinos      22       5       1       0    1     味スタ
# 3        shimizu-s-pulse      10       7       1       1    0     広島ビ
# 4        albirex-niigata      21      78       2       1    1     等々力
# ..                   ...     ...     ...     ...     ...  ...     ...
# 301      kashima-antlers      29       1       1       1    0    ＮＤスタ
# 302          vissel-kobe       3      18       0       4    2      埼玉
# 303      shonan-bellmare      78      12       3       1    1    東北電ス
# 304  sanfrecce-hiroshima       8      10       2       1    1     豊田ス
# 305         jubilo-iwata      20      13       6       2    1    金鳥スタ
#
#     Attendances
# 0        10,440
# 1        11,280
# 2        29,011
# 3        16,216
# 4        22,117
# ..          ...
# 301      13,647
# 302      45,941
# 303      27,389
# 304      31,941
# 305      15,011
#
# [306 rows x 13 columns]

# %%
df["Attendances"] = df["Attendances"].str.replace(',','').astype(int)
df
# Out:
#      Year  Sec                 Date                  Home Score  \
# 0    2010    1  2010-03-06 00:00:00          jubilo-iwata   0-1
# 1    2010    1  2010-03-06 00:00:00       shonan-bellmare   1-1
# 2    2010    1  2010-03-06 00:00:00              fc-tokyo   1-0
# 3    2010    1  2010-03-06 00:00:00   sanfrecce-hiroshima   1-1
# 4    2010    1  2010-03-06 00:00:00     kawasaki-frontale   2-1
# ..    ...  ...                  ...                   ...   ...
# 301  2010   34  2010-12-04 00:00:00     montedio-yamagata   1-1
# 302  2010   34  2010-12-04 00:00:00    urawa-red-diamonds   0-4
# 303  2010   34  2010-12-04 00:00:00       albirex-niigata   3-1
# 304  2010   34  2010-12-04 00:00:00  nagoya-grampus-eight   2-1
# 305  2010   34  2010-12-04 00:00:00          cerezo-osaka   6-2
#
#                     Away  HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  \
# 0         vegalta-sendai      13      54       0       1    2     ヤマハ
# 1      montedio-yamagata      12      29       1       1    0      平塚
# 2    yokohama-fa-marinos      22       5       1       0    1     味スタ
# 3        shimizu-s-pulse      10       7       1       1    0     広島ビ
# 4        albirex-niigata      21      78       2       1    1     等々力
# ..                   ...     ...     ...     ...     ...  ...     ...
# 301      kashima-antlers      29       1       1       1    0    ＮＤスタ
# 302          vissel-kobe       3      18       0       4    2      埼玉
# 303      shonan-bellmare      78      12       3       1    1    東北電ス
# 304  sanfrecce-hiroshima       8      10       2       1    1     豊田ス
# 305         jubilo-iwata      20      13       6       2    1    金鳥スタ
#
#      Attendances
# 0          10440
# 1          11280
# 2          29011
# 3          16216
# 4          22117
# ..           ...
# 301        13647
# 302        45941
# 303        27389
# 304        31941
# 305        15011
#
# [306 rows x 13 columns]

# %%
df.insert(13 ,"HomeElo", np.nan)
df.insert(14,"AwayElo",np.nan)
df.insert(15 ,"HomeED", np.nan)
df.insert(16,"AwayED",np.nan)

for index,row in df.iterrows():
    df_home = pd.read_csv(f'./elo_rating_data/{row["Home"]}.csv')
    df_away = pd.read_csv(f'./elo_rating_data/{row["Away"]}.csv')
    df_home["Month"] = pd.to_datetime(df_home["Month"])
    df_away["Month"] = pd.to_datetime(df_away["Month"])
    for i,r in df_home.iterrows():
        if row["Date"].year == r["Month"].year and row["Date"].month == r["Month"].month:
            df.at[index,"HomeElo"] = r["Points"]
            df.at[index,"HomeED"] = r["PD"]
    for i,r in df_away.iterrows():
        if row["Date"].year == r["Month"].year and row["Date"].month == r["Month"].month:
            df.at[index,"AwayElo"] = r["Points"]
            df.at[index,"AwayED"] = r["PD"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-c61ec65a804d> in <module>
#       5
#       6 for index,row in df.iterrows():
# ----> 7     df_home = pd.read_csv(f'./elo_rating_data/{row["Home"]}.csv')
#       8     df_away = pd.read_csv(f'./elo_rating_data/{row["Away"]}.csv')
#       9     df_home["Month"] = pd.to_datetime(df_home["Month"])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './elo_rating_data/jubilo-iwata.csv'
