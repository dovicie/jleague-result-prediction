# %%
import re
import csv
import time
import requests
import datetime
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
import os
import glob

csvs = glob.glob('./match_data_yearly/*.csv')
df_match = pd.DataFrame()
for csv in csvs:
    df_match = df_match.append(pd.read_csv(csv))

# df_match = pd.read_csv("./match_data_yearly/2006.csv")
df_match = df_match.sort_values(['Date','Sec']).reset_index(drop=True)
df_match
# Out:
#       Year  Sec                 Date                  Home  \
# 0     2006    1  2006-03-04 00:00:00           gamba-osaka
# 1     2006    1  2006-03-05 00:00:00        ventforet-kofu
# 2     2006    1  2006-03-05 00:00:00              fc-tokyo
# 3     2006    1  2006-03-05 00:00:00          jubilo-iwata
# 4     2006    1  2006-03-05 00:00:00  nagoya-grampus-eight
# ...    ...  ...                  ...                   ...
# 4585  2020   34  2020-12-19 00:00:00       kashima-antlers
# 4586  2020   34  2020-12-19 00:00:00  nagoya-grampus-eight
# 4587  2020   34  2020-12-19 00:00:00            sagan-tosu
# 4588  2020   34  2020-12-19 00:00:00              fc-tokyo
# 4589  2020   34  2020-12-19 00:00:00    urawa-red-diamonds
#
#                      Away  HomeID  AwayID  HomeGF  AwayGF  W/L Stadium  \
# 0      urawa-red-diamonds       9       3       1       1    0      万博
# 1         shimizu-s-pulse      28       7       0       2    2      小瀬
# 2            oita-trinita      22      31       2       0    1     味スタ
# 3          avispa-fukuoka      13      23       1       1    0      静岡
# 4            cerezo-osaka       8      20       3       2    1     瑞穂陸
# ...                   ...     ...     ...     ...     ...  ...     ...
# 4585         cerezo-osaka       1      20       1       1    0     カシマ
# 4586  sanfrecce-hiroshima       8      10       1       0    1     豊田ス
# 4587         oita-trinita      33      31       2       2    0     駅スタ
# 4588          vissel-kobe      22      18       1       0    1     味スタ
# 4589    consadole-sapporo       3      14       0       2    2      埼玉
#
#       Attendances
# 0           20916
# 1           14277
# 2           22531
# 3           28564
# 4           17199
# ...           ...
# 4585        11251
# 4586        16825
# 4587         8966
# 4588        14373
# 4589        19319
#
# [4590 rows x 12 columns]

# %%
df_club = pd.read_csv("./club_and_id.csv")
df_club
# Out:
#     club_id                  club club_ja
# 0         1       kashima-antlers      鹿島
# 1         2            jef-united      千葉
# 2         3    urawa-red-diamonds      浦和
# 3         4           tokyo-verdy     東京Ｖ
# 4         5   yokohama-fa-marinos    横浜FM
# 5         6      yokohama-flugels     横浜Ｆ
# 6         7       shimizu-s-pulse      清水
# 7         8  nagoya-grampus-eight     名古屋
# 8         9           gamba-osaka     Ｇ大阪
# 9        10   sanfrecce-hiroshima      広島
# 10       11        kashiwa-reysol       柏
# 11       12       shonan-bellmare      湘南
# 12       13          jubilo-iwata      磐田
# 13       14     consadole-sapporo      札幌
# 14       18           vissel-kobe      神戸
# 15       20          cerezo-osaka     Ｃ大阪
# 16       21     kawasaki-frontale     川崎Ｆ
# 17       22              fc-tokyo    FC東京
# 18       23        avispa-fukuoka      福岡
# 19       24           kyoto-sanga      京都
# 20       27          omiya-ardija      大宮
# 21       28        ventforet-kofu      甲府
# 22       29     montedio-yamagata      山形
# 23       31          oita-trinita      大分
# 24       33            sagan-tosu      鳥栖
# 25       34           yokohama-fc    横浜FC
# 26       36      tokushima-vortis      徳島
# 27       46      matsumoto-yamaga      松本
# 28       47      v-varen-nagasaki      長崎
# 29       54        vegalta-sendai      仙台
# 30       78       albirex-niigata      新潟
# 31       22              fc-tokyo     Ｆ東京

# %%
club_ids = list(df_club["club_id"])[:-1:]
clubs = list(df_club["club"])[:-1:]
initial_rates = [1600,1560,1600,1360,1520,1360,1440,1440,1600,1520,1360,1360,1560,1360,1360,1560,1520,1480,1400,1400,1440,1400,1360,1480,1360,1360,1360,1360,1360,1360,1480]

# %%
date_index = pd.date_range(start="2006-03-04", end="2020-12-20", freq="D")

# %%
df_elo=pd.DataFrame(columns=clubs,index = date_index )
df_elo
# Out:
#            kashima-antlers jef-united urawa-red-diamonds tokyo-verdy  \
# 2006-03-04             NaN        NaN                NaN         NaN
# 2006-03-05             NaN        NaN                NaN         NaN
# 2006-03-06             NaN        NaN                NaN         NaN
# 2006-03-07             NaN        NaN                NaN         NaN
# 2006-03-08             NaN        NaN                NaN         NaN
# ...                    ...        ...                ...         ...
# 2020-12-16             NaN        NaN                NaN         NaN
# 2020-12-17             NaN        NaN                NaN         NaN
# 2020-12-18             NaN        NaN                NaN         NaN
# 2020-12-19             NaN        NaN                NaN         NaN
# 2020-12-20             NaN        NaN                NaN         NaN
#
#            yokohama-fa-marinos yokohama-flugels shimizu-s-pulse  \
# 2006-03-04                 NaN              NaN             NaN
# 2006-03-05                 NaN              NaN             NaN
# 2006-03-06                 NaN              NaN             NaN
# 2006-03-07                 NaN              NaN             NaN
# 2006-03-08                 NaN              NaN             NaN
# ...                        ...              ...             ...
# 2020-12-16                 NaN              NaN             NaN
# 2020-12-17                 NaN              NaN             NaN
# 2020-12-18                 NaN              NaN             NaN
# 2020-12-19                 NaN              NaN             NaN
# 2020-12-20                 NaN              NaN             NaN
#
#            nagoya-grampus-eight gamba-osaka sanfrecce-hiroshima  ...  \
# 2006-03-04                  NaN         NaN                 NaN  ...
# 2006-03-05                  NaN         NaN                 NaN  ...
# 2006-03-06                  NaN         NaN                 NaN  ...
# 2006-03-07                  NaN         NaN                 NaN  ...
# 2006-03-08                  NaN         NaN                 NaN  ...
# ...                         ...         ...                 ...  ...
# 2020-12-16                  NaN         NaN                 NaN  ...
# 2020-12-17                  NaN         NaN                 NaN  ...
# 2020-12-18                  NaN         NaN                 NaN  ...
# 2020-12-19                  NaN         NaN                 NaN  ...
# 2020-12-20                  NaN         NaN                 NaN  ...
#
#            ventforet-kofu montedio-yamagata oita-trinita sagan-tosu  \
# 2006-03-04            NaN               NaN          NaN        NaN
# 2006-03-05            NaN               NaN          NaN        NaN
# 2006-03-06            NaN               NaN          NaN        NaN
# 2006-03-07            NaN               NaN          NaN        NaN
# 2006-03-08            NaN               NaN          NaN        NaN
# ...                   ...               ...          ...        ...
# 2020-12-16            NaN               NaN          NaN        NaN
# 2020-12-17            NaN               NaN          NaN        NaN
# 2020-12-18            NaN               NaN          NaN        NaN
# 2020-12-19            NaN               NaN          NaN        NaN
# 2020-12-20            NaN               NaN          NaN        NaN
#
#            yokohama-fc tokushima-vortis matsumoto-yamaga v-varen-nagasaki  \
# 2006-03-04         NaN              NaN              NaN              NaN
# 2006-03-05         NaN              NaN              NaN              NaN
# 2006-03-06         NaN              NaN              NaN              NaN
# 2006-03-07         NaN              NaN              NaN              NaN
# 2006-03-08         NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 2020-12-16         NaN              NaN              NaN              NaN
# 2020-12-17         NaN              NaN              NaN              NaN
# 2020-12-18         NaN              NaN              NaN              NaN
# 2020-12-19         NaN              NaN              NaN              NaN
# 2020-12-20         NaN              NaN              NaN              NaN
#
#            vegalta-sendai albirex-niigata
# 2006-03-04            NaN             NaN
# 2006-03-05            NaN             NaN
# 2006-03-06            NaN             NaN
# 2006-03-07            NaN             NaN
# 2006-03-08            NaN             NaN
# ...                   ...             ...
# 2020-12-16            NaN             NaN
# 2020-12-17            NaN             NaN
# 2020-12-18            NaN             NaN
# 2020-12-19            NaN             NaN
# 2020-12-20            NaN             NaN
#
# [5406 rows x 31 columns]

# %%
df_elo.loc["2006-03-04"] = [1600,1560,1600,1360,1520,1360,1440,1440,1600,1520,1360,1360,1560,1360,1360,1560,1520,1480,1400,1400,1440,1400,1360,1480,1360,1360,1360,1360,1360,1360,1480]
df_elo
# Out:
#            kashima-antlers jef-united urawa-red-diamonds tokyo-verdy  \
# 2006-03-04            1600       1560               1600        1360
# 2006-03-05             NaN        NaN                NaN         NaN
# 2006-03-06             NaN        NaN                NaN         NaN
# 2006-03-07             NaN        NaN                NaN         NaN
# 2006-03-08             NaN        NaN                NaN         NaN
# ...                    ...        ...                ...         ...
# 2020-12-16             NaN        NaN                NaN         NaN
# 2020-12-17             NaN        NaN                NaN         NaN
# 2020-12-18             NaN        NaN                NaN         NaN
# 2020-12-19             NaN        NaN                NaN         NaN
# 2020-12-20             NaN        NaN                NaN         NaN
#
#            yokohama-fa-marinos yokohama-flugels shimizu-s-pulse  \
# 2006-03-04                1520             1360            1440
# 2006-03-05                 NaN              NaN             NaN
# 2006-03-06                 NaN              NaN             NaN
# 2006-03-07                 NaN              NaN             NaN
# 2006-03-08                 NaN              NaN             NaN
# ...                        ...              ...             ...
# 2020-12-16                 NaN              NaN             NaN
# 2020-12-17                 NaN              NaN             NaN
# 2020-12-18                 NaN              NaN             NaN
# 2020-12-19                 NaN              NaN             NaN
# 2020-12-20                 NaN              NaN             NaN
#
#            nagoya-grampus-eight gamba-osaka sanfrecce-hiroshima  ...  \
# 2006-03-04                 1440        1600                1520  ...
# 2006-03-05                  NaN         NaN                 NaN  ...
# 2006-03-06                  NaN         NaN                 NaN  ...
# 2006-03-07                  NaN         NaN                 NaN  ...
# 2006-03-08                  NaN         NaN                 NaN  ...
# ...                         ...         ...                 ...  ...
# 2020-12-16                  NaN         NaN                 NaN  ...
# 2020-12-17                  NaN         NaN                 NaN  ...
# 2020-12-18                  NaN         NaN                 NaN  ...
# 2020-12-19                  NaN         NaN                 NaN  ...
# 2020-12-20                  NaN         NaN                 NaN  ...
#
#            ventforet-kofu montedio-yamagata oita-trinita sagan-tosu  \
# 2006-03-04           1400              1360         1480       1360
# 2006-03-05            NaN               NaN          NaN        NaN
# 2006-03-06            NaN               NaN          NaN        NaN
# 2006-03-07            NaN               NaN          NaN        NaN
# 2006-03-08            NaN               NaN          NaN        NaN
# ...                   ...               ...          ...        ...
# 2020-12-16            NaN               NaN          NaN        NaN
# 2020-12-17            NaN               NaN          NaN        NaN
# 2020-12-18            NaN               NaN          NaN        NaN
# 2020-12-19            NaN               NaN          NaN        NaN
# 2020-12-20            NaN               NaN          NaN        NaN
#
#            yokohama-fc tokushima-vortis matsumoto-yamaga v-varen-nagasaki  \
# 2006-03-04        1360             1360             1360             1360
# 2006-03-05         NaN              NaN              NaN              NaN
# 2006-03-06         NaN              NaN              NaN              NaN
# 2006-03-07         NaN              NaN              NaN              NaN
# 2006-03-08         NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 2020-12-16         NaN              NaN              NaN              NaN
# 2020-12-17         NaN              NaN              NaN              NaN
# 2020-12-18         NaN              NaN              NaN              NaN
# 2020-12-19         NaN              NaN              NaN              NaN
# 2020-12-20         NaN              NaN              NaN              NaN
#
#            vegalta-sendai albirex-niigata
# 2006-03-04           1360            1480
# 2006-03-05            NaN             NaN
# 2006-03-06            NaN             NaN
# 2006-03-07            NaN             NaN
# 2006-03-08            NaN             NaN
# ...                   ...             ...
# 2020-12-16            NaN             NaN
# 2020-12-17            NaN             NaN
# 2020-12-18            NaN             NaN
# 2020-12-19            NaN             NaN
# 2020-12-20            NaN             NaN
#
# [5406 rows x 31 columns]

# %%
df_match["Date"] =  pd.to_datetime(df_match["Date"])
df_match
# Out:
#       Year  Sec       Date                  Home                 Away  HomeID  \
# 0     2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds       9
# 1     2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse      28
# 2     2006    1 2006-03-05              fc-tokyo         oita-trinita      22
# 3     2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka      13
# 4     2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka       8
# ...    ...  ...        ...                   ...                  ...     ...
# 4585  2020   34 2020-12-19       kashima-antlers         cerezo-osaka       1
# 4586  2020   34 2020-12-19  nagoya-grampus-eight  sanfrecce-hiroshima       8
# 4587  2020   34 2020-12-19            sagan-tosu         oita-trinita      33
# 4588  2020   34 2020-12-19              fc-tokyo          vissel-kobe      22
# 4589  2020   34 2020-12-19    urawa-red-diamonds    consadole-sapporo       3
#
#       AwayID  HomeGF  AwayGF  W/L Stadium  Attendances
# 0          3       1       1    0      万博        20916
# 1          7       0       2    2      小瀬        14277
# 2         31       2       0    1     味スタ        22531
# 3         23       1       1    0      静岡        28564
# 4         20       3       2    1     瑞穂陸        17199
# ...      ...     ...     ...  ...     ...          ...
# 4585      20       1       1    0     カシマ        11251
# 4586      10       1       0    1     豊田ス        16825
# 4587      31       2       2    0     駅スタ         8966
# 4588      18       1       0    1     味スタ        14373
# 4589      14       0       2    2      埼玉        19319
#
# [4590 rows x 12 columns]

# %%
def calculate_rate(home_rate,away_rate,g):
    k=16
    e = 1 /(1+pow(10, (away_rate-home_rate)/400) )
    home_rate =  home_rate+k*(g-e)
    away_rate = away_rate+k*(abs(g-1)-(1-e))
    return home_rate,away_rate

# %%
g=0
def calculate_g(n):
    if n == 1:
        g=1
    elif n == 0:
        g=0.5
    else:
        g=0
        
    return g

# %%
# for index,row in df_elo.iterrows():
#     for i,r in df_match.iterrows():
#         if index == r["Date"] :
            
#             home_rate= df_elo.loc[index, r["Home"]]
#             away_rate= df_elo.loc[index, r["Away"]]
            
# #             print(home_rate, away_rate, calculate_g(r["W/L"]))

#             home_rate_upd = calculate_rate(home_rate, away_rate, calculate_g(r["W/L"]))[0]
#             away_rate_upd = calculate_rate(home_rate, away_rate, calculate_g(r["W/L"]))[1]
            
#             df_elo.at[index+pd.tseries.offsets.Day(),r["Home"]] = home_rate_upd
#             df_elo.at[index+pd.tseries.offsets.Day(), r["Away"]] = away_rate_upd
            
#         else:
            
            
#             print(home_rate_upd,away_rate_upd)
#             row[r["Home"]] = calculate_rate(home_rate, away_rate, calculate_g(r["W/L"]))[0]
#             row[r["Away"]] = calculate_rate(home_rate, away_rate, calculate_g(r["W/L"]))[1]    
            
            
# for index, row in df_match.iterrows():
#     for i,r in df_elo.iterrows():
        
#         if i == row["Date"]:            
#             home_rate= df_elo.loc[i, row["Home"]]
#             away_rate= df_elo.loc[i, row["Away"]]
            
#             print(home_rate,away_rate)
            
#             home_rate_upd = calculate_rate(home_rate, away_rate, calculate_g(row["W/L"]))[0]
#             away_rate_upd = calculate_rate(home_rate, away_rate, calculate_g(row["W/L"]))[1] 
            
# #             row[r["Home"]] = calculate_rate(home_rate, away_rate, calculate_g(r["W/L"]))[0]
# #             row[r["Away"]] = calculate_rate(home_rate, away_rate, calculate_g(r["W/L"]))[1]    
#             df_elo.at[i + pd.tseries.offsets.Day(),row["Home"]] = home_rate_upd
#             df_elo.at[i + pd.tseries.offsets.Day(),row["Away"]] = away_rate_upd

# for d in

# %%
df_elo.index[0]+pd.tseries.offsets.Day()
# Out:
# Timestamp('2006-03-05 00:00:00', freq='D')

# %%
df_elo
# Out:
#            kashima-antlers jef-united urawa-red-diamonds tokyo-verdy  \
# 2006-03-04            1600       1560               1600        1360
# 2006-03-05             NaN        NaN                NaN         NaN
# 2006-03-06             NaN        NaN                NaN         NaN
# 2006-03-07             NaN        NaN                NaN         NaN
# 2006-03-08             NaN        NaN                NaN         NaN
# ...                    ...        ...                ...         ...
# 2020-12-16             NaN        NaN                NaN         NaN
# 2020-12-17             NaN        NaN                NaN         NaN
# 2020-12-18             NaN        NaN                NaN         NaN
# 2020-12-19             NaN        NaN                NaN         NaN
# 2020-12-20             NaN        NaN                NaN         NaN
#
#            yokohama-fa-marinos yokohama-flugels shimizu-s-pulse  \
# 2006-03-04                1520             1360            1440
# 2006-03-05                 NaN              NaN             NaN
# 2006-03-06                 NaN              NaN             NaN
# 2006-03-07                 NaN              NaN             NaN
# 2006-03-08                 NaN              NaN             NaN
# ...                        ...              ...             ...
# 2020-12-16                 NaN              NaN             NaN
# 2020-12-17                 NaN              NaN             NaN
# 2020-12-18                 NaN              NaN             NaN
# 2020-12-19                 NaN              NaN             NaN
# 2020-12-20                 NaN              NaN             NaN
#
#            nagoya-grampus-eight gamba-osaka sanfrecce-hiroshima  ...  \
# 2006-03-04                 1440        1600                1520  ...
# 2006-03-05                  NaN         NaN                 NaN  ...
# 2006-03-06                  NaN         NaN                 NaN  ...
# 2006-03-07                  NaN         NaN                 NaN  ...
# 2006-03-08                  NaN         NaN                 NaN  ...
# ...                         ...         ...                 ...  ...
# 2020-12-16                  NaN         NaN                 NaN  ...
# 2020-12-17                  NaN         NaN                 NaN  ...
# 2020-12-18                  NaN         NaN                 NaN  ...
# 2020-12-19                  NaN         NaN                 NaN  ...
# 2020-12-20                  NaN         NaN                 NaN  ...
#
#            ventforet-kofu montedio-yamagata oita-trinita sagan-tosu  \
# 2006-03-04           1400              1360         1480       1360
# 2006-03-05            NaN               NaN          NaN        NaN
# 2006-03-06            NaN               NaN          NaN        NaN
# 2006-03-07            NaN               NaN          NaN        NaN
# 2006-03-08            NaN               NaN          NaN        NaN
# ...                   ...               ...          ...        ...
# 2020-12-16            NaN               NaN          NaN        NaN
# 2020-12-17            NaN               NaN          NaN        NaN
# 2020-12-18            NaN               NaN          NaN        NaN
# 2020-12-19            NaN               NaN          NaN        NaN
# 2020-12-20            NaN               NaN          NaN        NaN
#
#            yokohama-fc tokushima-vortis matsumoto-yamaga v-varen-nagasaki  \
# 2006-03-04        1360             1360             1360             1360
# 2006-03-05         NaN              NaN              NaN              NaN
# 2006-03-06         NaN              NaN              NaN              NaN
# 2006-03-07         NaN              NaN              NaN              NaN
# 2006-03-08         NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 2020-12-16         NaN              NaN              NaN              NaN
# 2020-12-17         NaN              NaN              NaN              NaN
# 2020-12-18         NaN              NaN              NaN              NaN
# 2020-12-19         NaN              NaN              NaN              NaN
# 2020-12-20         NaN              NaN              NaN              NaN
#
#            vegalta-sendai albirex-niigata
# 2006-03-04           1360            1480
# 2006-03-05            NaN             NaN
# 2006-03-06            NaN             NaN
# 2006-03-07            NaN             NaN
# 2006-03-08            NaN             NaN
# ...                   ...             ...
# 2020-12-16            NaN             NaN
# 2020-12-17            NaN             NaN
# 2020-12-18            NaN             NaN
# 2020-12-19            NaN             NaN
# 2020-12-20            NaN             NaN
#
# [5406 rows x 31 columns]

# %%
df_match
# Out:
#       Year  Sec       Date                  Home                 Away  HomeID  \
# 0     2006    1 2006-03-04           gamba-osaka   urawa-red-diamonds       9
# 1     2006    1 2006-03-05        ventforet-kofu      shimizu-s-pulse      28
# 2     2006    1 2006-03-05              fc-tokyo         oita-trinita      22
# 3     2006    1 2006-03-05          jubilo-iwata       avispa-fukuoka      13
# 4     2006    1 2006-03-05  nagoya-grampus-eight         cerezo-osaka       8
# ...    ...  ...        ...                   ...                  ...     ...
# 4585  2020   34 2020-12-19       kashima-antlers         cerezo-osaka       1
# 4586  2020   34 2020-12-19  nagoya-grampus-eight  sanfrecce-hiroshima       8
# 4587  2020   34 2020-12-19            sagan-tosu         oita-trinita      33
# 4588  2020   34 2020-12-19              fc-tokyo          vissel-kobe      22
# 4589  2020   34 2020-12-19    urawa-red-diamonds    consadole-sapporo       3
#
#       AwayID  HomeGF  AwayGF  W/L Stadium  Attendances
# 0          3       1       1    0      万博        20916
# 1          7       0       2    2      小瀬        14277
# 2         31       2       0    1     味スタ        22531
# 3         23       1       1    0      静岡        28564
# 4         20       3       2    1     瑞穂陸        17199
# ...      ...     ...     ...  ...     ...          ...
# 4585      20       1       1    0     カシマ        11251
# 4586      10       1       0    1     豊田ス        16825
# 4587      31       2       2    0     駅スタ         8966
# 4588      18       1       0    1     味スタ        14373
# 4589      14       0       2    2      埼玉        19319
#
# [4590 rows x 12 columns]

# %%
for date in date_index:
    next_date = date+pd.tseries.offsets.Day()
    prev_date = date-pd.tseries.offsets.Day()
    
    for index, row in df_match.iterrows():
        if row["Date"] == date:
            
            home_rate= df_elo.loc[date ,row["Home"]]
            away_rate= df_elo.loc[date ,row["Away"]]
            g = calculate_g(row["W/L"])
            
            home_rate_upd,away_rate_upd = calculate_rate(home_rate, away_rate, g)
            
            df_elo.at[next_date, row["Home"]] = home_rate_upd
            df_elo.at[next_date, row["Away"]] = away_rate_upd
            
    
    df_elo[:-1:].loc[next_date]=df_elo[:-1:].loc[next_date].fillna(df_elo.loc[date])
# Out:
# /home/yokoyama/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-15-9e0c109f395c>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_elo[:-1:].loc[next_date]=df_elo[:-1:].loc[next_date].fillna(df_elo.loc[date])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1608422400000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2020-12-20 00:00:00', freq='D')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     624         try:
# --> 625             return Index.get_loc(self, key, method, tolerance)
#     626         except KeyError as err:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#
# KeyError: Timestamp('2020-12-20 00:00:00', freq='D')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-9e0c109f395c> in <module>
#      16
#      17
# ---> 18     df_elo[:-1:].loc[next_date]=df_elo[:-1:].loc[next_date].fillna(df_elo.loc[date])
#      19
#      20
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     625             return Index.get_loc(self, key, method, tolerance)
#     626         except KeyError as err:
# --> 627             raise KeyError(orig_key) from err
#     628
#     629     def _maybe_cast_for_get_loc(self, key) -> Timestamp:
#
# KeyError: Timestamp('2020-12-20 00:00:00', freq='D')

# %%
df_elo
# Out:
#            kashima-antlers jef-united urawa-red-diamonds tokyo-verdy  \
# 2006-03-04            1600       1560               1600        1360
# 2006-03-05            1600       1560               1600        1360
# 2006-03-06         1606.19    1549.34               1600        1360
# 2006-03-07         1606.19    1549.34               1600        1360
# 2006-03-08         1606.19    1549.34               1600        1360
# ...                    ...        ...                ...         ...
# 2020-12-16         1586.94    1406.88            1481.96      1386.4
# 2020-12-17         1586.94    1406.88            1477.91      1386.4
# 2020-12-18         1586.94    1406.88            1477.91      1386.4
# 2020-12-19         1586.94    1406.88            1477.91      1386.4
# 2020-12-20         1586.16        NaN            1469.29         NaN
#
#            yokohama-fa-marinos yokohama-flugels shimizu-s-pulse  \
# 2006-03-04                1520             1360            1440
# 2006-03-05                1520             1360            1440
# 2006-03-06             1525.34             1360         1447.08
# 2006-03-07             1525.34             1360         1447.08
# 2006-03-08             1525.34             1360         1447.08
# ...                        ...              ...             ...
# 2020-12-16             1536.18             1360         1400.09
# 2020-12-17             1536.18             1360         1392.14
# 2020-12-18             1536.18             1360         1392.14
# 2020-12-19             1536.18             1360         1392.14
# 2020-12-20             1523.99              NaN         1403.98
#
#            nagoya-grampus-eight gamba-osaka sanfrecce-hiroshima  ...  \
# 2006-03-04                 1440        1600                1520  ...
# 2006-03-05                 1440        1600                1520  ...
# 2006-03-06              1450.66        1600             1513.81  ...
# 2006-03-07              1450.66        1600             1513.81  ...
# 2006-03-08              1450.66        1600             1513.81  ...
# ...                         ...         ...                 ...  ...
# 2020-12-16              1507.37     1570.46             1525.64  ...
# 2020-12-17              1507.37     1573.78             1517.12  ...
# 2020-12-18              1507.37     1573.78             1517.12  ...
# 2020-12-19              1507.37     1573.78             1517.12  ...
# 2020-12-20               1515.6     1561.94             1508.89  ...
#
#            ventforet-kofu montedio-yamagata oita-trinita sagan-tosu  \
# 2006-03-04           1400              1360         1480       1360
# 2006-03-05           1400              1360         1480       1360
# 2006-03-06        1392.92              1360         1472       1360
# 2006-03-07        1392.92              1360         1472       1360
# 2006-03-08        1392.92              1360         1472       1360
# ...                   ...               ...          ...        ...
# 2020-12-16        1409.83            1349.4      1444.29     1435.1
# 2020-12-17        1409.83            1349.4      1451.15    1445.93
# 2020-12-18        1409.83            1349.4      1451.15    1445.93
# 2020-12-19        1409.83            1349.4      1451.15    1445.93
# 2020-12-20            NaN               NaN      1451.03    1446.05
#
#            yokohama-fc tokushima-vortis matsumoto-yamaga v-varen-nagasaki  \
# 2006-03-04        1360             1360             1360             1360
# 2006-03-05        1360             1360             1360             1360
# 2006-03-06        1360             1360             1360             1360
# 2006-03-07        1360             1360             1360             1360
# 2006-03-08        1360             1360             1360             1360
# ...                ...              ...              ...              ...
# 2020-12-16     1337.29          1308.03          1377.76          1364.42
# 2020-12-17     1333.97          1308.03          1377.76          1364.42
# 2020-12-18     1333.97          1308.03          1377.76          1364.42
# 2020-12-19     1333.97          1308.03          1377.76          1364.42
# 2020-12-20     1346.16              NaN              NaN              NaN
#
#            vegalta-sendai albirex-niigata
# 2006-03-04           1360            1480
# 2006-03-05           1360            1480
# 2006-03-06           1360         1472.92
# 2006-03-07           1360         1472.92
# 2006-03-08           1360         1472.92
# ...                   ...             ...
# 2020-12-16        1402.24         1400.31
# 2020-12-17        1410.19         1400.31
# 2020-12-18        1410.19         1400.31
# 2020-12-19        1410.19         1400.31
# 2020-12-20        1409.68             NaN
#
# [5406 rows x 31 columns]

# %%
df_elo["shimizu-s-pulse"]
# Out:
# 2006-03-04       1440
# 2006-03-05       1440
# 2006-03-06    1447.08
# 2006-03-07    1447.08
# 2006-03-08    1447.08
#                ...
# 2020-12-16    1400.09
# 2020-12-17    1392.14
# 2020-12-18    1392.14
# 2020-12-19    1392.14
# 2020-12-20    1403.98
# Freq: D, Name: shimizu-s-pulse, Length: 5406, dtype: object

# %%
import matplotlib.pyplot as plt
